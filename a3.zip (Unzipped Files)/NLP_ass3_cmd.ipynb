# %%
# %cd "/content/drive/My Drive/NLP Course/a3.zip (Unzipped Files)/student"
# Out:
# /content/drive/My Drive/NLP Course/a3.zip (Unzipped Files)/student

# %%
# !python parser_transitions.py part_c
# Out:
# SHIFT test passed!
# LEFT-ARC test passed!
# RIGHT-ARC test passed!
# parse test passed!

# %%
# !python parser_transitions.py part_d
# Out:
# minibatch_parse test passed!

# %%
# !python parser_model.py -e
# Out:
# Embedding_lookup sanity check passes!

# %%
# !python parser_model.py -f
# Out:
# Forward sanity check passes!

# %%
# !python run.py -d
# Out:
# ================================================================================
# INITIALIZING
# ================================================================================
# Loading data...
# took 12.01 seconds
# Building parser...
# took 0.03 seconds
# Loading pretrained embeddings...
# took 20.58 seconds
# Vectorizing data...
# took 0.05 seconds
# Preprocessing training data...
# took 1.10 seconds
# took 0.00 seconds
#
# ================================================================================
# TRAINING
# ================================================================================
# Epoch 1 out of 10
# 100% 48/48 [00:01<00:00, 27.72it/s]
# Average Train Loss: 0.7228627484291792
# Evaluating on dev set
# 125250it [00:00, 17621057.12it/s]
# - dev UAS: 53.49
# New best dev UAS! Saving model.
#
# Epoch 2 out of 10
# 100% 48/48 [00:01<00:00, 32.09it/s]
# Average Train Loss: 0.3638274458547433
# Evaluating on dev set
# 125250it [00:00, 17494308.04it/s]
# - dev UAS: 58.79
# New best dev UAS! Saving model.
#
# Epoch 3 out of 10
# 100% 48/48 [00:01<00:00, 32.96it/s]
# Average Train Loss: 0.3024134077131748
# Evaluating on dev set
# 125250it [00:00, 17609834.27it/s]
# - dev UAS: 61.55
# New best dev UAS! Saving model.
#
# Epoch 4 out of 10
# 100% 48/48 [00:01<00:00, 32.35it/s]
# Average Train Loss: 0.26722475700080395
# Evaluating on dev set
# 125250it [00:00, 17800175.38it/s]
# - dev UAS: 63.61
# New best dev UAS! Saving model.
#
# Epoch 5 out of 10
# 100% 48/48 [00:01<00:00, 32.31it/s]
# Average Train Loss: 0.23946553841233253
# Evaluating on dev set
# 125250it [00:00, 13992930.13it/s]
# - dev UAS: 63.63
# New best dev UAS! Saving model.
#
# Epoch 6 out of 10
# 100% 48/48 [00:01<00:00, 32.34it/s]
# Average Train Loss: 0.21853637664268413
# Evaluating on dev set
# 125250it [00:00, 17434507.37it/s]
# - dev UAS: 66.27
# New best dev UAS! Saving model.
#
# Epoch 7 out of 10
# 100% 48/48 [00:01<00:00, 32.08it/s]
# Average Train Loss: 0.19797265032927194
# Evaluating on dev set
# 125250it [00:00, 15047019.05it/s]
# - dev UAS: 66.89
# New best dev UAS! Saving model.
#
# Epoch 8 out of 10
# 100% 48/48 [00:01<00:00, 32.00it/s]
# Average Train Loss: 0.18272505855808654
# Evaluating on dev set
# 125250it [00:00, 17873454.55it/s]
# - dev UAS: 68.93
# New best dev UAS! Saving model.
#
# Epoch 9 out of 10
# 100% 48/48 [00:01<00:00, 32.56it/s]
# Average Train Loss: 0.17266698616246381
# Evaluating on dev set
# 125250it [00:00, 17438558.54it/s]
# - dev UAS: 68.90
#
# Epoch 10 out of 10
# 100% 48/48 [00:01<00:00, 32.32it/s]
# Average Train Loss: 0.15954488158846894
# Evaluating on dev set
# 125250it [00:00, 17696441.96it/s]
# - dev UAS: 70.52
# New best dev UAS! Saving model.

# %%
# !python run.py
# Out:
# ================================================================================
# INITIALIZING
# ================================================================================
# Loading data...
# took 1.65 seconds
# Building parser...
# took 1.25 seconds
# Loading pretrained embeddings...
# took 2.22 seconds
# Vectorizing data...
# took 1.54 seconds
# Preprocessing training data...
# took 35.85 seconds
# took 0.01 seconds
#
# ================================================================================
# TRAINING
# ================================================================================
# Epoch 1 out of 10
# 100% 1848/1848 [01:23<00:00, 22.08it/s]
# Average Train Loss: 0.1845640590559546
# Evaluating on dev set
# 1445850it [00:00, 57800154.77it/s]
# - dev UAS: 83.27
# New best dev UAS! Saving model.
#
# Epoch 2 out of 10
# 100% 1848/1848 [01:20<00:00, 22.91it/s]
# Average Train Loss: 0.11404422143659679
# Evaluating on dev set
# 1445850it [00:00, 57574070.68it/s]
# - dev UAS: 86.06
# New best dev UAS! Saving model.
#
# Epoch 3 out of 10
# 100% 1848/1848 [01:24<00:00, 21.77it/s]
# Average Train Loss: 0.09957182975042433
# Evaluating on dev set
# 1445850it [00:00, 48247960.78it/s]
# - dev UAS: 87.01
# New best dev UAS! Saving model.
#
# Epoch 4 out of 10
# 100% 1848/1848 [01:26<00:00, 24.06it/s]
# Average Train Loss: 0.0908305965327694
# Evaluating on dev set
# 1445850it [00:00, 58438461.24it/s]
# - dev UAS: 87.78
# New best dev UAS! Saving model.
#
# Epoch 5 out of 10
# 100% 1848/1848 [01:21<00:00, 22.63it/s]
# Average Train Loss: 0.08463147810349862
# Evaluating on dev set
# 1445850it [00:00, 59796034.57it/s]
# - dev UAS: 87.93
# New best dev UAS! Saving model.
#
# Epoch 6 out of 10
# 100% 1848/1848 [01:22<00:00, 22.49it/s]
# Average Train Loss: 0.07958815739292538
# Evaluating on dev set
# 1445850it [00:00, 59918924.59it/s]
# - dev UAS: 88.22
# New best dev UAS! Saving model.
#
# Epoch 7 out of 10
# 100% 1848/1848 [01:22<00:00, 24.46it/s]
# Average Train Loss: 0.07528187429887198
# Evaluating on dev set
# 1445850it [00:00, 59231270.89it/s]
# - dev UAS: 88.29
# New best dev UAS! Saving model.
#
# Epoch 8 out of 10
# 100% 1848/1848 [01:23<00:00, 22.15it/s]
# Average Train Loss: 0.07183591415299288
# Evaluating on dev set
# 1445850it [00:00, 58973796.21it/s]
# - dev UAS: 88.74
# New best dev UAS! Saving model.
#
# Epoch 9 out of 10
# 100% 1848/1848 [01:21<00:00, 24.21it/s]
# Average Train Loss: 0.06847952197616299
# Evaluating on dev set
# 1445850it [00:00, 58633958.62it/s]
# - dev UAS: 88.96
# New best dev UAS! Saving model.
#
# Epoch 10 out of 10
# 100% 1848/1848 [01:22<00:00, 22.37it/s]
# Average Train Loss: 0.06572555884460866
# Evaluating on dev set
# 1445850it [00:00, 59676583.73it/s]
# - dev UAS: 88.46
#
# ================================================================================
# TESTING
# ================================================================================
# Restoring the best model weights found on the dev set
# Final evaluation on test set
# 2919736it [00:00, 84634408.58it/s]
# - test UAS: 89.06
# Done!
