# %% [markdown]
# #cmd commands only

# %%
# %cd "/content/drive/My Drive/NLP Course/a4.zip (Unzipped Files)"
# Out:
# /content/drive/My Drive/NLP Course/a4.zip (Unzipped Files)

# %%
# !python sanity_check.py 1d
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Running Sanity Check for Question 1d: Encode
# --------------------------------------------------------------------------------
# enc_hiddens Sanity Checks Passed!
# dec_init_state[0] Sanity Checks Passed!
# dec_init_state[1] Sanity Checks Passed!
# --------------------------------------------------------------------------------
# All Sanity Checks Passed for Question 1d: Encode!
# --------------------------------------------------------------------------------

# %%
# !python sanity_check.py 1e
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 1e: Decode
# --------------------------------------------------------------------------------
# torch.Size([23, 5, 3])
# combined_outputs Sanity Checks Passed!
# --------------------------------------------------------------------------------
# All Sanity Checks Passed for Question 1e: Decode!
# --------------------------------------------------------------------------------

# %%
# !python sanity_check.py 1f
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 1f: Step
# --------------------------------------------------------------------------------
# dec_state[0] Sanity Checks Passed!
# dec_state[1] Sanity Checks Passed!
# combined_output  Sanity Checks Passed!
# e_t Sanity Checks Passed!
# --------------------------------------------------------------------------------
# All Sanity Checks Passed for Question 1f: Step!
# --------------------------------------------------------------------------------

# %%
# !sh run.sh vocab
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# read in source sentences: ./en_es_data/train.es
# read in target sentences: ./en_es_data/train.en
# initialize source vocabulary ..
# number of word types: 93286, number of word types w/ frequency >= 2: 52658
# initialize target vocabulary ..
# number of word types: 67535, number of word types w/ frequency >= 2: 39786
# generated vocabulary, source 50004 words, target 39788 words
# vocabulary saved to vocab.json

# %%
# !sh run.sh train
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 7, iter 41160, avg. loss 29.66, avg. ppl 4.31 cum. examples 37097, speed 5011.52 words/sec, time elapsed 5566.01 sec
# epoch 7, iter 41170, avg. loss 28.44, avg. ppl 4.06 cum. examples 37417, speed 4714.19 words/sec, time elapsed 5567.39 sec
# epoch 7, iter 41180, avg. loss 29.20, avg. ppl 4.16 cum. examples 37737, speed 4944.64 words/sec, time elapsed 5568.72 sec
# epoch 7, iter 41190, avg. loss 28.64, avg. ppl 4.09 cum. examples 38057, speed 5030.90 words/sec, time elapsed 5570.01 sec
# epoch 7, iter 41200, avg. loss 30.72, avg. ppl 4.26 cum. examples 38377, speed 4957.76 words/sec, time elapsed 5571.38 sec
# epoch 7, iter 41210, avg. loss 30.83, avg. ppl 4.26 cum. examples 38697, speed 5318.54 words/sec, time elapsed 5572.66 sec
# epoch 7, iter 41220, avg. loss 27.98, avg. ppl 4.00 cum. examples 39017, speed 4647.36 words/sec, time elapsed 5574.05 sec
# epoch 7, iter 41230, avg. loss 32.22, avg. ppl 4.20 cum. examples 39337, speed 5163.29 words/sec, time elapsed 5575.44 sec
# epoch 7, iter 41240, avg. loss 29.33, avg. ppl 4.37 cum. examples 39657, speed 4770.05 words/sec, time elapsed 5576.77 sec
# epoch 7, iter 41250, avg. loss 30.32, avg. ppl 4.46 cum. examples 39977, speed 4879.48 words/sec, time elapsed 5578.10 sec
# epoch 7, iter 41260, avg. loss 27.95, avg. ppl 4.09 cum. examples 40297, speed 4852.42 words/sec, time elapsed 5579.41 sec
# epoch 7, iter 41270, avg. loss 26.81, avg. ppl 4.04 cum. examples 40617, speed 5029.43 words/sec, time elapsed 5580.63 sec
# epoch 7, iter 41280, avg. loss 30.91, avg. ppl 4.35 cum. examples 40937, speed 4600.46 words/sec, time elapsed 5582.10 sec
# epoch 7, iter 41290, avg. loss 30.11, avg. ppl 4.27 cum. examples 41257, speed 4797.38 words/sec, time elapsed 5583.48 sec
# epoch 7, iter 41300, avg. loss 30.53, avg. ppl 4.54 cum. examples 41577, speed 4684.22 words/sec, time elapsed 5584.86 sec
# epoch 7, iter 41310, avg. loss 28.34, avg. ppl 4.06 cum. examples 41897, speed 4730.26 words/sec, time elapsed 5586.23 sec
# epoch 7, iter 41320, avg. loss 31.04, avg. ppl 4.50 cum. examples 42217, speed 4961.09 words/sec, time elapsed 5587.56 sec
# epoch 7, iter 41330, avg. loss 29.88, avg. ppl 4.15 cum. examples 42537, speed 4943.29 words/sec, time elapsed 5588.92 sec
# epoch 7, iter 41340, avg. loss 28.15, avg. ppl 4.27 cum. examples 42857, speed 4690.95 words/sec, time elapsed 5590.24 sec
# epoch 7, iter 41350, avg. loss 31.45, avg. ppl 4.38 cum. examples 43177, speed 5009.34 words/sec, time elapsed 5591.60 sec
# epoch 7, iter 41360, avg. loss 28.35, avg. ppl 4.28 cum. examples 43497, speed 4830.45 words/sec, time elapsed 5592.90 sec
# epoch 7, iter 41370, avg. loss 31.54, avg. ppl 4.71 cum. examples 43817, speed 4840.55 words/sec, time elapsed 5594.24 sec
# epoch 7, iter 41380, avg. loss 28.55, avg. ppl 4.27 cum. examples 44137, speed 5062.06 words/sec, time elapsed 5595.48 sec
# epoch 7, iter 41390, avg. loss 32.13, avg. ppl 4.56 cum. examples 44457, speed 4796.44 words/sec, time elapsed 5596.90 sec
# epoch 7, iter 41400, avg. loss 29.78, avg. ppl 4.20 cum. examples 44777, speed 5340.55 words/sec, time elapsed 5598.14 sec
# epoch 7, iter 41410, avg. loss 30.19, avg. ppl 4.17 cum. examples 45097, speed 4953.61 words/sec, time elapsed 5599.51 sec
# epoch 7, iter 41420, avg. loss 29.71, avg. ppl 4.28 cum. examples 45417, speed 4902.82 words/sec, time elapsed 5600.84 sec
# epoch 7, iter 41430, avg. loss 30.92, avg. ppl 4.29 cum. examples 45737, speed 5092.26 words/sec, time elapsed 5602.18 sec
# epoch 7, iter 41440, avg. loss 31.35, avg. ppl 4.65 cum. examples 46057, speed 4736.81 words/sec, time elapsed 5603.55 sec
# epoch 7, iter 41450, avg. loss 28.70, avg. ppl 4.33 cum. examples 46377, speed 4448.17 words/sec, time elapsed 5604.96 sec
# epoch 7, iter 41460, avg. loss 29.12, avg. ppl 4.09 cum. examples 46697, speed 5148.80 words/sec, time elapsed 5606.25 sec
# epoch 7, iter 41470, avg. loss 29.11, avg. ppl 4.20 cum. examples 47017, speed 5206.72 words/sec, time elapsed 5607.50 sec
# epoch 7, iter 41480, avg. loss 30.64, avg. ppl 4.45 cum. examples 47337, speed 4794.12 words/sec, time elapsed 5608.87 sec
# epoch 7, iter 41490, avg. loss 30.74, avg. ppl 4.54 cum. examples 47657, speed 4805.69 words/sec, time elapsed 5610.22 sec
# epoch 7, iter 41500, avg. loss 31.89, avg. ppl 4.48 cum. examples 47977, speed 4782.97 words/sec, time elapsed 5611.64 sec
# epoch 7, iter 41510, avg. loss 32.28, avg. ppl 4.53 cum. examples 48297, speed 5168.94 words/sec, time elapsed 5612.97 sec
# epoch 7, iter 41520, avg. loss 30.42, avg. ppl 4.19 cum. examples 48617, speed 5041.64 words/sec, time elapsed 5614.31 sec
# epoch 7, iter 41530, avg. loss 32.27, avg. ppl 4.75 cum. examples 48937, speed 4897.54 words/sec, time elapsed 5615.67 sec
# epoch 7, iter 41540, avg. loss 30.33, avg. ppl 4.37 cum. examples 49257, speed 4846.28 words/sec, time elapsed 5617.03 sec
# epoch 7, iter 41550, avg. loss 31.43, avg. ppl 4.44 cum. examples 49577, speed 5018.01 words/sec, time elapsed 5618.37 sec
# epoch 7, iter 41560, avg. loss 29.08, avg. ppl 4.06 cum. examples 49897, speed 5039.70 words/sec, time elapsed 5619.69 sec
# epoch 7, iter 41570, avg. loss 31.85, avg. ppl 4.61 cum. examples 50217, speed 5256.19 words/sec, time elapsed 5620.96 sec
# epoch 7, iter 41580, avg. loss 30.08, avg. ppl 4.70 cum. examples 50537, speed 4788.84 words/sec, time elapsed 5622.26 sec
# epoch 7, iter 41590, avg. loss 30.73, avg. ppl 4.39 cum. examples 50857, speed 4832.30 words/sec, time elapsed 5623.63 sec
# epoch 7, iter 41600, avg. loss 29.86, avg. ppl 4.42 cum. examples 51177, speed 5071.45 words/sec, time elapsed 5624.90 sec
# epoch 7, iter 41610, avg. loss 30.64, avg. ppl 4.32 cum. examples 51497, speed 5024.29 words/sec, time elapsed 5626.23 sec
# epoch 7, iter 41620, avg. loss 31.67, avg. ppl 4.39 cum. examples 51817, speed 4812.20 words/sec, time elapsed 5627.66 sec
# epoch 7, iter 41630, avg. loss 28.70, avg. ppl 4.21 cum. examples 52137, speed 4927.09 words/sec, time elapsed 5628.95 sec
# epoch 7, iter 41640, avg. loss 30.18, avg. ppl 4.45 cum. examples 52457, speed 5122.43 words/sec, time elapsed 5630.21 sec
# epoch 7, iter 41650, avg. loss 32.05, avg. ppl 4.56 cum. examples 52777, speed 4672.02 words/sec, time elapsed 5631.66 sec
# epoch 7, iter 41660, avg. loss 29.96, avg. ppl 4.26 cum. examples 53097, speed 4987.07 words/sec, time elapsed 5632.99 sec
# epoch 7, iter 41670, avg. loss 30.27, avg. ppl 4.30 cum. examples 53417, speed 4832.48 words/sec, time elapsed 5634.36 sec
# epoch 7, iter 41680, avg. loss 28.14, avg. ppl 4.05 cum. examples 53737, speed 5190.21 words/sec, time elapsed 5635.60 sec
# epoch 7, iter 41690, avg. loss 28.41, avg. ppl 4.14 cum. examples 54057, speed 4893.60 words/sec, time elapsed 5636.91 sec
# epoch 7, iter 41700, avg. loss 27.39, avg. ppl 4.04 cum. examples 54377, speed 4985.39 words/sec, time elapsed 5638.17 sec
# epoch 7, iter 41710, avg. loss 28.84, avg. ppl 4.32 cum. examples 54697, speed 4717.49 words/sec, time elapsed 5639.51 sec
# epoch 7, iter 41720, avg. loss 28.87, avg. ppl 4.32 cum. examples 55017, speed 4660.49 words/sec, time elapsed 5640.86 sec
# epoch 7, iter 41730, avg. loss 30.81, avg. ppl 4.31 cum. examples 55337, speed 5042.10 words/sec, time elapsed 5642.20 sec
# epoch 7, iter 41740, avg. loss 27.38, avg. ppl 4.02 cum. examples 55657, speed 4697.31 words/sec, time elapsed 5643.54 sec
# epoch 7, iter 41750, avg. loss 29.64, avg. ppl 4.30 cum. examples 55977, speed 4894.91 words/sec, time elapsed 5644.87 sec
# epoch 7, iter 41760, avg. loss 30.31, avg. ppl 4.18 cum. examples 56297, speed 5509.73 words/sec, time elapsed 5646.10 sec
# epoch 7, iter 41770, avg. loss 31.58, avg. ppl 4.36 cum. examples 56617, speed 5273.44 words/sec, time elapsed 5647.40 sec
# epoch 7, iter 41780, avg. loss 28.28, avg. ppl 4.05 cum. examples 56937, speed 4833.64 words/sec, time elapsed 5648.74 sec
# epoch 7, iter 41790, avg. loss 30.17, avg. ppl 4.26 cum. examples 57257, speed 5309.00 words/sec, time elapsed 5650.00 sec
# epoch 7, iter 41800, avg. loss 30.29, avg. ppl 4.43 cum. examples 57577, speed 4676.10 words/sec, time elapsed 5651.39 sec
# epoch 7, iter 41810, avg. loss 31.69, avg. ppl 4.47 cum. examples 57897, speed 5003.00 words/sec, time elapsed 5652.74 sec
# epoch 7, iter 41820, avg. loss 28.65, avg. ppl 4.05 cum. examples 58217, speed 5014.34 words/sec, time elapsed 5654.05 sec
# epoch 7, iter 41830, avg. loss 31.40, avg. ppl 4.32 cum. examples 58537, speed 4765.27 words/sec, time elapsed 5655.49 sec
# epoch 7, iter 41840, avg. loss 29.57, avg. ppl 4.12 cum. examples 58857, speed 4952.72 words/sec, time elapsed 5656.84 sec
# epoch 7, iter 41850, avg. loss 28.52, avg. ppl 4.07 cum. examples 59177, speed 5118.29 words/sec, time elapsed 5658.11 sec
# epoch 7, iter 41860, avg. loss 30.40, avg. ppl 4.46 cum. examples 59497, speed 4877.28 words/sec, time elapsed 5659.45 sec
# epoch 7, iter 41870, avg. loss 28.61, avg. ppl 4.11 cum. examples 59817, speed 4957.98 words/sec, time elapsed 5660.75 sec
# epoch 7, iter 41880, avg. loss 31.30, avg. ppl 4.34 cum. examples 60137, speed 5222.89 words/sec, time elapsed 5662.06 sec
# epoch 7, iter 41890, avg. loss 29.14, avg. ppl 4.27 cum. examples 60457, speed 4969.62 words/sec, time elapsed 5663.35 sec
# epoch 7, iter 41900, avg. loss 29.35, avg. ppl 4.19 cum. examples 60777, speed 4650.33 words/sec, time elapsed 5664.76 sec
# epoch 7, iter 41910, avg. loss 31.31, avg. ppl 4.44 cum. examples 61097, speed 4917.40 words/sec, time elapsed 5666.13 sec
# epoch 7, iter 41920, avg. loss 31.44, avg. ppl 4.49 cum. examples 61417, speed 4994.69 words/sec, time elapsed 5667.47 sec
# epoch 7, iter 41930, avg. loss 29.37, avg. ppl 4.26 cum. examples 61737, speed 4962.62 words/sec, time elapsed 5668.78 sec
# epoch 7, iter 41940, avg. loss 30.11, avg. ppl 4.35 cum. examples 62057, speed 4883.36 words/sec, time elapsed 5670.12 sec
# epoch 7, iter 41950, avg. loss 30.91, avg. ppl 4.64 cum. examples 62377, speed 4668.04 words/sec, time elapsed 5671.50 sec
# epoch 7, iter 41960, avg. loss 28.18, avg. ppl 4.10 cum. examples 62697, speed 4948.73 words/sec, time elapsed 5672.79 sec
# epoch 7, iter 41970, avg. loss 29.38, avg. ppl 4.20 cum. examples 63017, speed 5155.36 words/sec, time elapsed 5674.06 sec
# epoch 7, iter 41980, avg. loss 29.40, avg. ppl 4.06 cum. examples 63337, speed 4863.08 words/sec, time elapsed 5675.44 sec
# epoch 7, iter 41990, avg. loss 30.98, avg. ppl 4.03 cum. examples 63657, speed 5269.16 words/sec, time elapsed 5676.79 sec
# epoch 7, iter 42000, avg. loss 30.62, avg. ppl 4.41 cum. examples 63977, speed 4863.07 words/sec, time elapsed 5678.15 sec
# epoch 7, iter 42000, cum. loss 30.50, cum. ppl 4.39 cum. examples 63977
# begin validation ...
# validation: iter 42000, dev. ppl 7.284454
# hit patience 1
# epoch 7, iter 42010, avg. loss 31.71, avg. ppl 4.46 cum. examples 320, speed 3221.47 words/sec, time elapsed 5680.25 sec
# epoch 7, iter 42020, avg. loss 28.82, avg. ppl 4.01 cum. examples 640, speed 5035.09 words/sec, time elapsed 5681.57 sec
# epoch 7, iter 42030, avg. loss 27.55, avg. ppl 3.95 cum. examples 960, speed 4956.02 words/sec, time elapsed 5682.87 sec
# epoch 7, iter 42040, avg. loss 32.47, avg. ppl 4.64 cum. examples 1280, speed 4999.17 words/sec, time elapsed 5684.22 sec
# epoch 7, iter 42050, avg. loss 29.51, avg. ppl 4.22 cum. examples 1600, speed 4730.54 words/sec, time elapsed 5685.61 sec
# epoch 7, iter 42060, avg. loss 29.47, avg. ppl 4.27 cum. examples 1920, speed 4747.06 words/sec, time elapsed 5686.98 sec
# epoch 7, iter 42070, avg. loss 29.94, avg. ppl 4.34 cum. examples 2240, speed 4606.77 words/sec, time elapsed 5688.40 sec
# epoch 7, iter 42080, avg. loss 30.36, avg. ppl 4.39 cum. examples 2560, speed 4910.78 words/sec, time elapsed 5689.73 sec
# epoch 7, iter 42090, avg. loss 30.68, avg. ppl 4.33 cum. examples 2880, speed 4739.05 words/sec, time elapsed 5691.15 sec
# epoch 7, iter 42100, avg. loss 29.80, avg. ppl 4.51 cum. examples 3200, speed 4689.16 words/sec, time elapsed 5692.50 sec
# epoch 7, iter 42110, avg. loss 31.46, avg. ppl 4.35 cum. examples 3520, speed 4695.83 words/sec, time elapsed 5693.96 sec
# epoch 7, iter 42120, avg. loss 31.22, avg. ppl 4.51 cum. examples 3840, speed 5174.06 words/sec, time elapsed 5695.24 sec
# epoch 7, iter 42130, avg. loss 30.94, avg. ppl 4.50 cum. examples 4160, speed 5095.02 words/sec, time elapsed 5696.53 sec
# epoch 7, iter 42140, avg. loss 27.10, avg. ppl 4.04 cum. examples 4480, speed 5004.03 words/sec, time elapsed 5697.77 sec
# epoch 7, iter 42150, avg. loss 29.92, avg. ppl 4.17 cum. examples 4800, speed 4627.24 words/sec, time elapsed 5699.22 sec
# epoch 7, iter 42160, avg. loss 30.98, avg. ppl 4.47 cum. examples 5120, speed 4942.53 words/sec, time elapsed 5700.56 sec
# epoch 7, iter 42170, avg. loss 30.35, avg. ppl 4.25 cum. examples 5440, speed 5066.13 words/sec, time elapsed 5701.89 sec
# epoch 7, iter 42180, avg. loss 28.57, avg. ppl 4.35 cum. examples 5760, speed 4668.16 words/sec, time elapsed 5703.22 sec
# epoch 7, iter 42190, avg. loss 29.67, avg. ppl 4.07 cum. examples 6080, speed 4807.72 words/sec, time elapsed 5704.63 sec
# epoch 7, iter 42200, avg. loss 28.37, avg. ppl 4.21 cum. examples 6400, speed 5039.93 words/sec, time elapsed 5705.88 sec
# epoch 7, iter 42210, avg. loss 29.19, avg. ppl 4.25 cum. examples 6720, speed 4545.69 words/sec, time elapsed 5707.30 sec
# epoch 7, iter 42220, avg. loss 30.00, avg. ppl 4.29 cum. examples 7040, speed 4660.73 words/sec, time elapsed 5708.71 sec
# epoch 7, iter 42230, avg. loss 29.45, avg. ppl 4.22 cum. examples 7360, speed 5069.89 words/sec, time elapsed 5710.00 sec
# epoch 7, iter 42240, avg. loss 29.25, avg. ppl 4.06 cum. examples 7680, speed 4985.41 words/sec, time elapsed 5711.34 sec
# epoch 7, iter 42250, avg. loss 29.36, avg. ppl 4.17 cum. examples 8000, speed 5346.97 words/sec, time elapsed 5712.57 sec
# epoch 7, iter 42260, avg. loss 34.25, avg. ppl 4.79 cum. examples 8320, speed 5023.12 words/sec, time elapsed 5713.97 sec
# epoch 7, iter 42270, avg. loss 30.94, avg. ppl 4.32 cum. examples 8640, speed 5105.63 words/sec, time elapsed 5715.29 sec
# epoch 7, iter 42280, avg. loss 29.67, avg. ppl 4.23 cum. examples 8960, speed 4939.36 words/sec, time elapsed 5716.62 sec
# epoch 7, iter 42290, avg. loss 30.58, avg. ppl 4.57 cum. examples 9280, speed 5090.03 words/sec, time elapsed 5717.89 sec
# epoch 7, iter 42300, avg. loss 31.40, avg. ppl 4.34 cum. examples 9600, speed 5230.68 words/sec, time elapsed 5719.20 sec
# epoch 7, iter 42310, avg. loss 33.05, avg. ppl 4.51 cum. examples 9920, speed 5196.05 words/sec, time elapsed 5720.55 sec
# epoch 7, iter 42320, avg. loss 30.61, avg. ppl 4.20 cum. examples 10240, speed 5423.60 words/sec, time elapsed 5721.81 sec
# epoch 7, iter 42330, avg. loss 29.51, avg. ppl 4.19 cum. examples 10560, speed 4905.56 words/sec, time elapsed 5723.15 sec
# epoch 7, iter 42340, avg. loss 30.00, avg. ppl 4.32 cum. examples 10880, speed 4710.39 words/sec, time elapsed 5724.54 sec
# epoch 7, iter 42350, avg. loss 30.85, avg. ppl 4.34 cum. examples 11200, speed 4985.45 words/sec, time elapsed 5725.89 sec
# epoch 7, iter 42360, avg. loss 29.83, avg. ppl 4.44 cum. examples 11520, speed 4798.63 words/sec, time elapsed 5727.23 sec
# epoch 7, iter 42370, avg. loss 28.75, avg. ppl 4.19 cum. examples 11840, speed 4976.12 words/sec, time elapsed 5728.52 sec
# epoch 7, iter 42380, avg. loss 28.77, avg. ppl 4.22 cum. examples 12160, speed 5191.98 words/sec, time elapsed 5729.75 sec
# epoch 7, iter 42390, avg. loss 28.86, avg. ppl 4.09 cum. examples 12480, speed 5072.18 words/sec, time elapsed 5731.04 sec
# epoch 7, iter 42400, avg. loss 30.28, avg. ppl 4.09 cum. examples 12800, speed 4715.64 words/sec, time elapsed 5732.50 sec
# epoch 7, iter 42410, avg. loss 30.55, avg. ppl 4.51 cum. examples 13120, speed 5071.03 words/sec, time elapsed 5733.78 sec
# epoch 7, iter 42420, avg. loss 28.41, avg. ppl 4.22 cum. examples 13440, speed 4827.92 words/sec, time elapsed 5735.09 sec
# epoch 7, iter 42430, avg. loss 31.13, avg. ppl 4.49 cum. examples 13760, speed 4820.81 words/sec, time elapsed 5736.46 sec
# epoch 7, iter 42440, avg. loss 29.46, avg. ppl 4.25 cum. examples 14080, speed 5130.77 words/sec, time elapsed 5737.73 sec
# epoch 7, iter 42450, avg. loss 29.82, avg. ppl 4.27 cum. examples 14400, speed 5174.33 words/sec, time elapsed 5739.00 sec
# epoch 7, iter 42460, avg. loss 31.18, avg. ppl 4.42 cum. examples 14720, speed 4726.30 words/sec, time elapsed 5740.42 sec
# epoch 7, iter 42470, avg. loss 30.74, avg. ppl 4.40 cum. examples 15040, speed 5052.03 words/sec, time elapsed 5741.73 sec
# epoch 7, iter 42480, avg. loss 29.09, avg. ppl 4.21 cum. examples 15360, speed 4940.07 words/sec, time elapsed 5743.04 sec
# epoch 7, iter 42490, avg. loss 29.29, avg. ppl 4.09 cum. examples 15680, speed 5281.09 words/sec, time elapsed 5744.30 sec
# epoch 7, iter 42500, avg. loss 30.20, avg. ppl 4.49 cum. examples 16000, speed 4988.02 words/sec, time elapsed 5745.60 sec
# epoch 7, iter 42510, avg. loss 31.08, avg. ppl 4.53 cum. examples 16320, speed 4875.08 words/sec, time elapsed 5746.95 sec
# epoch 7, iter 42520, avg. loss 31.37, avg. ppl 4.52 cum. examples 16640, speed 4875.70 words/sec, time elapsed 5748.31 sec
# epoch 7, iter 42530, avg. loss 31.55, avg. ppl 4.37 cum. examples 16960, speed 5083.28 words/sec, time elapsed 5749.66 sec
# epoch 7, iter 42540, avg. loss 29.86, avg. ppl 4.14 cum. examples 17280, speed 5014.36 words/sec, time elapsed 5751.00 sec
# epoch 7, iter 42550, avg. loss 28.72, avg. ppl 4.48 cum. examples 17600, speed 4399.17 words/sec, time elapsed 5752.39 sec
# epoch 7, iter 42560, avg. loss 28.10, avg. ppl 4.08 cum. examples 17920, speed 5195.24 words/sec, time elapsed 5753.62 sec
# epoch 7, iter 42570, avg. loss 30.85, avg. ppl 4.39 cum. examples 18240, speed 4876.31 words/sec, time elapsed 5754.99 sec
# epoch 7, iter 42580, avg. loss 32.89, avg. ppl 4.53 cum. examples 18560, speed 4867.76 words/sec, time elapsed 5756.42 sec
# epoch 7, iter 42590, avg. loss 31.28, avg. ppl 4.45 cum. examples 18880, speed 5115.27 words/sec, time elapsed 5757.74 sec
# epoch 7, iter 42600, avg. loss 27.68, avg. ppl 4.08 cum. examples 19200, speed 5124.74 words/sec, time elapsed 5758.97 sec
# epoch 7, iter 42610, avg. loss 29.95, avg. ppl 4.29 cum. examples 19520, speed 5249.29 words/sec, time elapsed 5760.22 sec
# epoch 7, iter 42620, avg. loss 31.53, avg. ppl 4.56 cum. examples 19840, speed 4738.53 words/sec, time elapsed 5761.62 sec
# epoch 7, iter 42630, avg. loss 29.76, avg. ppl 4.11 cum. examples 20160, speed 4666.28 words/sec, time elapsed 5763.06 sec
# epoch 7, iter 42640, avg. loss 32.41, avg. ppl 4.61 cum. examples 20480, speed 5024.21 words/sec, time elapsed 5764.42 sec
# epoch 7, iter 42650, avg. loss 27.53, avg. ppl 4.22 cum. examples 20800, speed 4879.99 words/sec, time elapsed 5765.67 sec
# epoch 7, iter 42660, avg. loss 30.51, avg. ppl 4.36 cum. examples 21120, speed 4941.96 words/sec, time elapsed 5767.01 sec
# epoch 7, iter 42670, avg. loss 28.90, avg. ppl 4.26 cum. examples 21440, speed 5034.50 words/sec, time elapsed 5768.28 sec
# epoch 7, iter 42680, avg. loss 33.35, avg. ppl 4.69 cum. examples 21760, speed 5022.22 words/sec, time elapsed 5769.66 sec
# epoch 7, iter 42690, avg. loss 31.54, avg. ppl 4.58 cum. examples 22080, speed 4894.29 words/sec, time elapsed 5771.01 sec
# epoch 7, iter 42700, avg. loss 31.03, avg. ppl 4.56 cum. examples 22400, speed 4547.16 words/sec, time elapsed 5772.45 sec
# epoch 7, iter 42710, avg. loss 28.27, avg. ppl 3.97 cum. examples 22720, speed 4791.28 words/sec, time elapsed 5773.82 sec
# epoch 7, iter 42720, avg. loss 30.31, avg. ppl 4.26 cum. examples 23040, speed 4604.18 words/sec, time elapsed 5775.27 sec
# epoch 7, iter 42730, avg. loss 32.22, avg. ppl 4.68 cum. examples 23360, speed 4971.57 words/sec, time elapsed 5776.62 sec
# epoch 7, iter 42740, avg. loss 29.02, avg. ppl 4.16 cum. examples 23680, speed 4903.22 words/sec, time elapsed 5777.95 sec
# epoch 7, iter 42750, avg. loss 29.91, avg. ppl 4.47 cum. examples 24000, speed 4597.92 words/sec, time elapsed 5779.33 sec
# epoch 7, iter 42760, avg. loss 29.66, avg. ppl 4.27 cum. examples 24320, speed 4775.07 words/sec, time elapsed 5780.70 sec
# epoch 7, iter 42770, avg. loss 30.23, avg. ppl 4.26 cum. examples 24640, speed 5244.81 words/sec, time elapsed 5781.98 sec
# epoch 7, iter 42780, avg. loss 30.74, avg. ppl 4.32 cum. examples 24960, speed 4922.06 words/sec, time elapsed 5783.34 sec
# epoch 7, iter 42790, avg. loss 28.21, avg. ppl 4.05 cum. examples 25280, speed 4979.17 words/sec, time elapsed 5784.64 sec
# epoch 7, iter 42800, avg. loss 29.70, avg. ppl 4.18 cum. examples 25600, speed 4506.05 words/sec, time elapsed 5786.11 sec
# epoch 7, iter 42810, avg. loss 31.74, avg. ppl 4.43 cum. examples 25920, speed 4956.49 words/sec, time elapsed 5787.49 sec
# epoch 7, iter 42820, avg. loss 31.46, avg. ppl 4.74 cum. examples 26240, speed 4859.95 words/sec, time elapsed 5788.82 sec
# epoch 7, iter 42830, avg. loss 32.12, avg. ppl 4.32 cum. examples 26560, speed 4984.41 words/sec, time elapsed 5790.23 sec
# epoch 7, iter 42840, avg. loss 28.65, avg. ppl 4.22 cum. examples 26880, speed 4728.19 words/sec, time elapsed 5791.58 sec
# epoch 7, iter 42850, avg. loss 29.21, avg. ppl 4.30 cum. examples 27200, speed 4865.30 words/sec, time elapsed 5792.90 sec
# epoch 7, iter 42860, avg. loss 29.44, avg. ppl 4.45 cum. examples 27520, speed 5143.35 words/sec, time elapsed 5794.12 sec
# epoch 7, iter 42870, avg. loss 30.20, avg. ppl 4.19 cum. examples 27840, speed 5005.36 words/sec, time elapsed 5795.47 sec
# epoch 7, iter 42880, avg. loss 30.57, avg. ppl 4.48 cum. examples 28160, speed 4858.28 words/sec, time elapsed 5796.81 sec
# epoch 7, iter 42890, avg. loss 29.22, avg. ppl 4.33 cum. examples 28480, speed 5090.20 words/sec, time elapsed 5798.07 sec
# epoch 7, iter 42900, avg. loss 29.87, avg. ppl 4.55 cum. examples 28800, speed 4756.67 words/sec, time elapsed 5799.39 sec
# epoch 7, iter 42910, avg. loss 31.40, avg. ppl 4.38 cum. examples 29120, speed 4746.71 words/sec, time elapsed 5800.83 sec
# epoch 7, iter 42920, avg. loss 27.91, avg. ppl 4.19 cum. examples 29440, speed 4926.13 words/sec, time elapsed 5802.09 sec
# epoch 7, iter 42930, avg. loss 29.48, avg. ppl 4.16 cum. examples 29760, speed 5155.68 words/sec, time elapsed 5803.38 sec
# epoch 7, iter 42940, avg. loss 30.62, avg. ppl 4.30 cum. examples 30080, speed 5101.72 words/sec, time elapsed 5804.69 sec
# epoch 7, iter 42950, avg. loss 28.38, avg. ppl 4.23 cum. examples 30400, speed 4939.76 words/sec, time elapsed 5805.97 sec
# epoch 7, iter 42960, avg. loss 30.02, avg. ppl 4.25 cum. examples 30720, speed 5079.09 words/sec, time elapsed 5807.27 sec
# epoch 7, iter 42970, avg. loss 29.60, avg. ppl 4.21 cum. examples 31040, speed 5150.03 words/sec, time elapsed 5808.55 sec
# epoch 7, iter 42980, avg. loss 31.27, avg. ppl 4.47 cum. examples 31360, speed 4996.49 words/sec, time elapsed 5809.89 sec
# epoch 7, iter 42990, avg. loss 28.50, avg. ppl 4.39 cum. examples 31680, speed 4631.81 words/sec, time elapsed 5811.22 sec
# epoch 7, iter 43000, avg. loss 29.30, avg. ppl 4.49 cum. examples 32000, speed 4905.78 words/sec, time elapsed 5812.50 sec
# epoch 7, iter 43010, avg. loss 30.95, avg. ppl 4.28 cum. examples 32320, speed 5045.91 words/sec, time elapsed 5813.85 sec
# epoch 7, iter 43020, avg. loss 30.24, avg. ppl 4.39 cum. examples 32640, speed 5007.92 words/sec, time elapsed 5815.15 sec
# epoch 7, iter 43030, avg. loss 28.56, avg. ppl 4.28 cum. examples 32960, speed 5158.62 words/sec, time elapsed 5816.37 sec
# epoch 7, iter 43040, avg. loss 29.41, avg. ppl 4.07 cum. examples 33280, speed 4959.09 words/sec, time elapsed 5817.72 sec
# epoch 7, iter 43050, avg. loss 30.51, avg. ppl 4.32 cum. examples 33600, speed 5274.23 words/sec, time elapsed 5818.99 sec
# epoch 7, iter 43060, avg. loss 32.31, avg. ppl 4.59 cum. examples 33920, speed 5205.59 words/sec, time elapsed 5820.29 sec
# epoch 7, iter 43070, avg. loss 30.42, avg. ppl 4.44 cum. examples 34240, speed 5070.38 words/sec, time elapsed 5821.58 sec
# epoch 7, iter 43080, avg. loss 30.01, avg. ppl 4.27 cum. examples 34560, speed 5426.29 words/sec, time elapsed 5822.80 sec
# epoch 7, iter 43090, avg. loss 28.43, avg. ppl 4.26 cum. examples 34880, speed 4980.92 words/sec, time elapsed 5824.06 sec
# epoch 7, iter 43100, avg. loss 30.73, avg. ppl 4.30 cum. examples 35200, speed 5120.74 words/sec, time elapsed 5825.38 sec
# epoch 7, iter 43110, avg. loss 31.36, avg. ppl 4.66 cum. examples 35520, speed 5096.97 words/sec, time elapsed 5826.66 sec
# epoch 7, iter 43120, avg. loss 29.50, avg. ppl 4.34 cum. examples 35840, speed 5312.63 words/sec, time elapsed 5827.87 sec
# epoch 7, iter 43130, avg. loss 30.73, avg. ppl 4.56 cum. examples 36160, speed 5157.79 words/sec, time elapsed 5829.12 sec
# epoch 7, iter 43140, avg. loss 30.29, avg. ppl 4.28 cum. examples 36480, speed 4811.11 words/sec, time elapsed 5830.51 sec
# epoch 7, iter 43150, avg. loss 32.21, avg. ppl 4.66 cum. examples 36800, speed 4903.34 words/sec, time elapsed 5831.88 sec
# epoch 7, iter 43160, avg. loss 29.26, avg. ppl 4.50 cum. examples 37120, speed 4814.90 words/sec, time elapsed 5833.17 sec
# epoch 7, iter 43170, avg. loss 29.78, avg. ppl 4.30 cum. examples 37440, speed 4531.21 words/sec, time elapsed 5834.61 sec
# epoch 7, iter 43180, avg. loss 31.03, avg. ppl 4.39 cum. examples 37760, speed 4853.23 words/sec, time elapsed 5835.99 sec
# epoch 7, iter 43190, avg. loss 28.79, avg. ppl 4.17 cum. examples 38080, speed 4707.67 words/sec, time elapsed 5837.36 sec
# epoch 7, iter 43200, avg. loss 30.32, avg. ppl 4.39 cum. examples 38400, speed 4817.59 words/sec, time elapsed 5838.72 sec
# epoch 7, iter 43210, avg. loss 30.70, avg. ppl 4.59 cum. examples 38720, speed 4909.60 words/sec, time elapsed 5840.03 sec
# epoch 7, iter 43220, avg. loss 30.74, avg. ppl 4.48 cum. examples 39040, speed 4845.33 words/sec, time elapsed 5841.39 sec
# epoch 7, iter 43230, avg. loss 32.47, avg. ppl 4.60 cum. examples 39360, speed 5168.41 words/sec, time elapsed 5842.71 sec
# epoch 7, iter 43240, avg. loss 28.67, avg. ppl 4.39 cum. examples 39680, speed 4714.80 words/sec, time elapsed 5844.02 sec
# epoch 7, iter 43250, avg. loss 30.01, avg. ppl 4.48 cum. examples 40000, speed 4629.35 words/sec, time elapsed 5845.41 sec
# epoch 7, iter 43260, avg. loss 33.19, avg. ppl 4.46 cum. examples 40320, speed 5273.55 words/sec, time elapsed 5846.75 sec
# epoch 7, iter 43270, avg. loss 30.86, avg. ppl 4.48 cum. examples 40640, speed 4963.16 words/sec, time elapsed 5848.08 sec
# epoch 7, iter 43280, avg. loss 31.62, avg. ppl 4.35 cum. examples 40960, speed 5112.42 words/sec, time elapsed 5849.43 sec
# epoch 7, iter 43290, avg. loss 30.24, avg. ppl 4.51 cum. examples 41280, speed 5202.74 words/sec, time elapsed 5850.66 sec
# epoch 7, iter 43300, avg. loss 29.24, avg. ppl 4.34 cum. examples 41600, speed 4778.02 words/sec, time elapsed 5851.99 sec
# epoch 7, iter 43310, avg. loss 27.99, avg. ppl 4.22 cum. examples 41920, speed 5134.74 words/sec, time elapsed 5853.21 sec
# epoch 7, iter 43320, avg. loss 29.40, avg. ppl 4.09 cum. examples 42240, speed 5086.38 words/sec, time elapsed 5854.52 sec
# epoch 7, iter 43330, avg. loss 29.87, avg. ppl 4.20 cum. examples 42560, speed 4911.08 words/sec, time elapsed 5855.88 sec
# epoch 7, iter 43340, avg. loss 27.78, avg. ppl 4.00 cum. examples 42880, speed 5044.49 words/sec, time elapsed 5857.15 sec
# epoch 7, iter 43350, avg. loss 29.72, avg. ppl 4.19 cum. examples 43200, speed 5094.41 words/sec, time elapsed 5858.45 sec
# epoch 7, iter 43360, avg. loss 28.54, avg. ppl 4.39 cum. examples 43520, speed 4505.20 words/sec, time elapsed 5859.82 sec
# epoch 7, iter 43370, avg. loss 31.87, avg. ppl 4.61 cum. examples 43840, speed 5028.24 words/sec, time elapsed 5861.15 sec
# epoch 7, iter 43380, avg. loss 31.51, avg. ppl 4.37 cum. examples 44160, speed 4930.48 words/sec, time elapsed 5862.53 sec
# epoch 7, iter 43390, avg. loss 31.12, avg. ppl 4.42 cum. examples 44480, speed 4993.39 words/sec, time elapsed 5863.88 sec
# epoch 7, iter 43400, avg. loss 29.46, avg. ppl 4.17 cum. examples 44800, speed 4775.97 words/sec, time elapsed 5865.26 sec
# epoch 7, iter 43410, avg. loss 30.64, avg. ppl 4.36 cum. examples 45120, speed 4965.64 words/sec, time elapsed 5866.60 sec
# epoch 7, iter 43420, avg. loss 30.86, avg. ppl 4.39 cum. examples 45440, speed 4866.96 words/sec, time elapsed 5867.97 sec
# epoch 7, iter 43430, avg. loss 35.08, avg. ppl 4.88 cum. examples 45760, speed 5195.43 words/sec, time elapsed 5869.33 sec
# epoch 7, iter 43440, avg. loss 31.10, avg. ppl 4.39 cum. examples 46080, speed 5046.24 words/sec, time elapsed 5870.66 sec
# epoch 7, iter 43450, avg. loss 28.64, avg. ppl 3.96 cum. examples 46400, speed 5021.10 words/sec, time elapsed 5871.99 sec
# epoch 7, iter 43460, avg. loss 28.03, avg. ppl 4.19 cum. examples 46720, speed 5009.93 words/sec, time elapsed 5873.24 sec
# epoch 7, iter 43470, avg. loss 31.55, avg. ppl 4.23 cum. examples 47040, speed 4972.98 words/sec, time elapsed 5874.65 sec
# epoch 7, iter 43480, avg. loss 30.96, avg. ppl 4.67 cum. examples 47360, speed 4767.79 words/sec, time elapsed 5876.00 sec
# epoch 7, iter 43490, avg. loss 30.53, avg. ppl 4.27 cum. examples 47680, speed 4634.28 words/sec, time elapsed 5877.45 sec
# epoch 7, iter 43500, avg. loss 32.22, avg. ppl 4.62 cum. examples 48000, speed 5000.53 words/sec, time elapsed 5878.80 sec
# epoch 7, iter 43510, avg. loss 32.63, avg. ppl 4.35 cum. examples 48320, speed 5068.62 words/sec, time elapsed 5880.20 sec
# epoch 7, iter 43520, avg. loss 31.38, avg. ppl 4.82 cum. examples 48640, speed 4808.24 words/sec, time elapsed 5881.53 sec
# epoch 7, iter 43530, avg. loss 32.93, avg. ppl 4.66 cum. examples 48960, speed 4850.91 words/sec, time elapsed 5882.94 sec
# epoch 7, iter 43540, avg. loss 29.02, avg. ppl 4.46 cum. examples 49280, speed 4954.95 words/sec, time elapsed 5884.19 sec
# epoch 7, iter 43550, avg. loss 30.32, avg. ppl 4.45 cum. examples 49600, speed 5209.66 words/sec, time elapsed 5885.44 sec
# epoch 7, iter 43560, avg. loss 31.27, avg. ppl 4.70 cum. examples 49920, speed 5066.87 words/sec, time elapsed 5886.72 sec
# epoch 7, iter 43570, avg. loss 29.94, avg. ppl 4.16 cum. examples 50240, speed 4645.57 words/sec, time elapsed 5888.16 sec
# epoch 7, iter 43580, avg. loss 30.37, avg. ppl 4.23 cum. examples 50560, speed 5249.88 words/sec, time elapsed 5889.45 sec
# epoch 7, iter 43590, avg. loss 30.31, avg. ppl 4.42 cum. examples 50880, speed 4622.02 words/sec, time elapsed 5890.86 sec
# epoch 7, iter 43600, avg. loss 31.06, avg. ppl 4.28 cum. examples 51200, speed 4893.30 words/sec, time elapsed 5892.25 sec
# epoch 7, iter 43610, avg. loss 29.74, avg. ppl 4.32 cum. examples 51520, speed 4784.91 words/sec, time elapsed 5893.61 sec
# epoch 7, iter 43620, avg. loss 29.29, avg. ppl 4.29 cum. examples 51840, speed 4640.42 words/sec, time elapsed 5895.00 sec
# epoch 7, iter 43630, avg. loss 29.78, avg. ppl 4.29 cum. examples 52160, speed 4920.24 words/sec, time elapsed 5896.33 sec
# epoch 7, iter 43640, avg. loss 31.62, avg. ppl 4.46 cum. examples 52480, speed 4956.51 words/sec, time elapsed 5897.70 sec
# epoch 7, iter 43650, avg. loss 30.22, avg. ppl 4.44 cum. examples 52800, speed 4824.88 words/sec, time elapsed 5899.04 sec
# epoch 7, iter 43660, avg. loss 30.87, avg. ppl 4.46 cum. examples 53120, speed 5069.10 words/sec, time elapsed 5900.34 sec
# epoch 7, iter 43670, avg. loss 32.02, avg. ppl 4.50 cum. examples 53440, speed 5288.79 words/sec, time elapsed 5901.63 sec
# epoch 7, iter 43680, avg. loss 29.50, avg. ppl 4.29 cum. examples 53760, speed 4675.59 words/sec, time elapsed 5903.02 sec
# epoch 7, iter 43690, avg. loss 32.10, avg. ppl 4.38 cum. examples 54080, speed 4841.95 words/sec, time elapsed 5904.45 sec
# epoch 7, iter 43700, avg. loss 31.73, avg. ppl 4.61 cum. examples 54400, speed 4665.47 words/sec, time elapsed 5905.88 sec
# epoch 7, iter 43710, avg. loss 34.01, avg. ppl 4.62 cum. examples 54720, speed 5022.68 words/sec, time elapsed 5907.29 sec
# epoch 7, iter 43720, avg. loss 30.06, avg. ppl 4.26 cum. examples 55040, speed 4984.73 words/sec, time elapsed 5908.62 sec
# epoch 7, iter 43730, avg. loss 30.58, avg. ppl 4.23 cum. examples 55360, speed 5034.36 words/sec, time elapsed 5909.97 sec
# epoch 7, iter 43740, avg. loss 29.12, avg. ppl 4.61 cum. examples 55680, speed 4902.04 words/sec, time elapsed 5911.21 sec
# epoch 7, iter 43750, avg. loss 29.59, avg. ppl 4.27 cum. examples 56000, speed 4965.59 words/sec, time elapsed 5912.53 sec
# epoch 7, iter 43760, avg. loss 31.94, avg. ppl 4.58 cum. examples 56320, speed 4985.27 words/sec, time elapsed 5913.88 sec
# epoch 7, iter 43770, avg. loss 29.56, avg. ppl 4.25 cum. examples 56640, speed 4905.50 words/sec, time elapsed 5915.21 sec
# epoch 7, iter 43780, avg. loss 30.56, avg. ppl 4.58 cum. examples 56960, speed 4949.83 words/sec, time elapsed 5916.51 sec
# epoch 7, iter 43790, avg. loss 29.64, avg. ppl 4.08 cum. examples 57280, speed 5146.90 words/sec, time elapsed 5917.82 sec
# epoch 7, iter 43800, avg. loss 29.30, avg. ppl 4.23 cum. examples 57600, speed 4767.95 words/sec, time elapsed 5919.18 sec
# epoch 7, iter 43810, avg. loss 30.20, avg. ppl 4.24 cum. examples 57920, speed 5041.57 words/sec, time elapsed 5920.51 sec
# epoch 7, iter 43820, avg. loss 28.01, avg. ppl 3.99 cum. examples 58240, speed 4690.74 words/sec, time elapsed 5921.89 sec
# epoch 7, iter 43830, avg. loss 30.74, avg. ppl 4.63 cum. examples 58560, speed 4826.57 words/sec, time elapsed 5923.22 sec
# epoch 7, iter 43840, avg. loss 28.00, avg. ppl 4.14 cum. examples 58880, speed 4853.44 words/sec, time elapsed 5924.52 sec
# epoch 7, iter 43850, avg. loss 29.98, avg. ppl 4.60 cum. examples 59200, speed 4572.06 words/sec, time elapsed 5925.89 sec
# epoch 7, iter 43860, avg. loss 29.70, avg. ppl 4.26 cum. examples 59520, speed 4878.92 words/sec, time elapsed 5927.24 sec
# epoch 7, iter 43870, avg. loss 31.79, avg. ppl 4.69 cum. examples 59840, speed 5148.76 words/sec, time elapsed 5928.52 sec
# epoch 7, iter 43880, avg. loss 30.84, avg. ppl 4.36 cum. examples 60160, speed 5010.12 words/sec, time elapsed 5929.85 sec
# epoch 7, iter 43890, avg. loss 29.44, avg. ppl 4.18 cum. examples 60480, speed 4845.02 words/sec, time elapsed 5931.21 sec
# epoch 7, iter 43900, avg. loss 31.07, avg. ppl 4.53 cum. examples 60800, speed 5017.03 words/sec, time elapsed 5932.53 sec
# epoch 7, iter 43910, avg. loss 28.10, avg. ppl 4.19 cum. examples 61120, speed 4651.91 words/sec, time elapsed 5933.88 sec
# epoch 7, iter 43920, avg. loss 28.06, avg. ppl 3.96 cum. examples 61440, speed 4829.39 words/sec, time elapsed 5935.23 sec
# epoch 7, iter 43930, avg. loss 33.47, avg. ppl 4.49 cum. examples 61760, speed 5100.00 words/sec, time elapsed 5936.63 sec
# epoch 7, iter 43940, avg. loss 28.93, avg. ppl 4.31 cum. examples 62080, speed 5137.29 words/sec, time elapsed 5937.86 sec
# epoch 7, iter 43950, avg. loss 32.43, avg. ppl 4.68 cum. examples 62400, speed 5079.05 words/sec, time elapsed 5939.18 sec
# epoch 7, iter 43960, avg. loss 29.10, avg. ppl 4.21 cum. examples 62720, speed 5011.73 words/sec, time elapsed 5940.48 sec
# epoch 7, iter 43970, avg. loss 30.70, avg. ppl 4.52 cum. examples 63040, speed 5221.54 words/sec, time elapsed 5941.72 sec
# epoch 7, iter 43980, avg. loss 31.43, avg. ppl 4.92 cum. examples 63360, speed 5087.46 words/sec, time elapsed 5942.96 sec
# epoch 7, iter 43990, avg. loss 32.14, avg. ppl 4.66 cum. examples 63680, speed 5017.17 words/sec, time elapsed 5944.29 sec
# epoch 7, iter 44000, avg. loss 31.53, avg. ppl 4.47 cum. examples 64000, speed 4972.83 words/sec, time elapsed 5945.65 sec
# epoch 7, iter 44000, cum. loss 30.28, cum. ppl 4.36 cum. examples 64000
# begin validation ...
# validation: iter 44000, dev. ppl 7.288610
# hit patience 2
# epoch 7, iter 44010, avg. loss 31.39, avg. ppl 4.45 cum. examples 320, speed 3226.52 words/sec, time elapsed 5947.74 sec
# epoch 7, iter 44020, avg. loss 30.35, avg. ppl 4.42 cum. examples 640, speed 5113.30 words/sec, time elapsed 5949.01 sec
# epoch 7, iter 44030, avg. loss 31.26, avg. ppl 4.65 cum. examples 960, speed 4751.48 words/sec, time elapsed 5950.38 sec
# epoch 7, iter 44040, avg. loss 30.48, avg. ppl 4.46 cum. examples 1280, speed 4912.64 words/sec, time elapsed 5951.71 sec
# epoch 7, iter 44050, avg. loss 30.89, avg. ppl 4.48 cum. examples 1600, speed 4945.96 words/sec, time elapsed 5953.04 sec
# epoch 7, iter 44060, avg. loss 31.95, avg. ppl 4.65 cum. examples 1920, speed 5087.53 words/sec, time elapsed 5954.35 sec
# epoch 7, iter 44070, avg. loss 30.16, avg. ppl 4.23 cum. examples 2240, speed 4904.23 words/sec, time elapsed 5955.72 sec
# epoch 7, iter 44080, avg. loss 29.99, avg. ppl 4.50 cum. examples 2560, speed 5016.13 words/sec, time elapsed 5956.99 sec
# epoch 7, iter 44090, avg. loss 29.72, avg. ppl 4.43 cum. examples 2880, speed 4687.19 words/sec, time elapsed 5958.35 sec
# epoch 7, iter 44100, avg. loss 30.74, avg. ppl 4.51 cum. examples 3200, speed 4726.43 words/sec, time elapsed 5959.73 sec
# epoch 7, iter 44110, avg. loss 32.04, avg. ppl 4.74 cum. examples 3520, speed 4727.18 words/sec, time elapsed 5961.13 sec
# epoch 7, iter 44120, avg. loss 28.68, avg. ppl 4.18 cum. examples 3840, speed 4830.34 words/sec, time elapsed 5962.46 sec
# epoch 7, iter 44130, avg. loss 27.16, avg. ppl 3.95 cum. examples 4160, speed 4785.68 words/sec, time elapsed 5963.78 sec
# epoch 7, iter 44140, avg. loss 31.84, avg. ppl 4.63 cum. examples 4480, speed 4843.61 words/sec, time elapsed 5965.15 sec
# epoch 7, iter 44150, avg. loss 29.34, avg. ppl 4.45 cum. examples 4800, speed 4844.45 words/sec, time elapsed 5966.45 sec
# epoch 7, iter 44160, avg. loss 32.17, avg. ppl 4.37 cum. examples 5120, speed 5083.44 words/sec, time elapsed 5967.83 sec
# epoch 7, iter 44170, avg. loss 29.57, avg. ppl 4.64 cum. examples 5440, speed 4596.89 words/sec, time elapsed 5969.17 sec
# epoch 7, iter 44180, avg. loss 28.17, avg. ppl 4.03 cum. examples 5760, speed 4835.82 words/sec, time elapsed 5970.50 sec
# epoch 7, iter 44190, avg. loss 29.45, avg. ppl 4.32 cum. examples 6080, speed 4849.29 words/sec, time elapsed 5971.83 sec
# epoch 7, iter 44200, avg. loss 30.36, avg. ppl 4.18 cum. examples 6400, speed 5094.61 words/sec, time elapsed 5973.16 sec
# epoch 7, iter 44210, avg. loss 29.77, avg. ppl 4.50 cum. examples 6720, speed 4653.98 words/sec, time elapsed 5974.52 sec
# epoch 7, iter 44220, avg. loss 29.70, avg. ppl 4.31 cum. examples 7040, speed 4860.88 words/sec, time elapsed 5975.86 sec
# epoch 7, iter 44230, avg. loss 31.06, avg. ppl 4.60 cum. examples 7360, speed 4648.12 words/sec, time elapsed 5977.27 sec
# epoch 7, iter 44240, avg. loss 31.66, avg. ppl 4.30 cum. examples 7680, speed 4983.65 words/sec, time elapsed 5978.66 sec
# epoch 7, iter 44250, avg. loss 30.37, avg. ppl 4.50 cum. examples 8000, speed 4839.92 words/sec, time elapsed 5979.99 sec
# epoch 7, iter 44260, avg. loss 32.26, avg. ppl 4.59 cum. examples 8320, speed 4917.32 words/sec, time elapsed 5981.37 sec
# epoch 7, iter 44270, avg. loss 31.96, avg. ppl 4.78 cum. examples 8640, speed 5060.48 words/sec, time elapsed 5982.66 sec
# epoch 7, iter 44280, avg. loss 31.38, avg. ppl 4.55 cum. examples 8960, speed 4492.12 words/sec, time elapsed 5984.14 sec
# epoch 7, iter 44290, avg. loss 29.44, avg. ppl 4.23 cum. examples 9280, speed 4878.68 words/sec, time elapsed 5985.48 sec
# epoch 7, iter 44300, avg. loss 30.15, avg. ppl 4.41 cum. examples 9600, speed 4804.51 words/sec, time elapsed 5986.83 sec
# epoch 7, iter 44310, avg. loss 30.71, avg. ppl 4.54 cum. examples 9920, speed 4874.69 words/sec, time elapsed 5988.16 sec
# epoch 7, iter 44320, avg. loss 30.68, avg. ppl 4.59 cum. examples 10240, speed 4709.26 words/sec, time elapsed 5989.53 sec
# epoch 7, iter 44330, avg. loss 32.83, avg. ppl 4.72 cum. examples 10560, speed 5029.93 words/sec, time elapsed 5990.88 sec
# epoch 7, iter 44340, avg. loss 30.62, avg. ppl 4.35 cum. examples 10880, speed 4960.02 words/sec, time elapsed 5992.22 sec
# epoch 7, iter 44350, avg. loss 29.82, avg. ppl 4.43 cum. examples 11200, speed 4792.05 words/sec, time elapsed 5993.56 sec
# epoch 7, iter 44360, avg. loss 28.81, avg. ppl 4.16 cum. examples 11520, speed 4784.66 words/sec, time elapsed 5994.91 sec
# epoch 7, iter 44370, avg. loss 30.78, avg. ppl 4.47 cum. examples 11840, speed 4990.03 words/sec, time elapsed 5996.23 sec
# epoch 7, iter 44380, avg. loss 29.18, avg. ppl 4.30 cum. examples 12160, speed 4557.77 words/sec, time elapsed 5997.64 sec
# epoch 7, iter 44390, avg. loss 30.83, avg. ppl 4.45 cum. examples 12480, speed 4729.66 words/sec, time elapsed 5999.03 sec
# epoch 7, iter 44400, avg. loss 32.15, avg. ppl 4.43 cum. examples 12800, speed 5076.95 words/sec, time elapsed 6000.40 sec
# epoch 7, iter 44410, avg. loss 31.69, avg. ppl 4.40 cum. examples 13120, speed 4977.39 words/sec, time elapsed 6001.77 sec
# epoch 7, iter 44420, avg. loss 30.15, avg. ppl 4.71 cum. examples 13440, speed 4774.10 words/sec, time elapsed 6003.08 sec
# epoch 7, iter 44430, avg. loss 31.82, avg. ppl 4.41 cum. examples 13760, speed 4852.86 words/sec, time elapsed 6004.49 sec
# epoch 7, iter 44440, avg. loss 30.88, avg. ppl 4.58 cum. examples 14080, speed 5042.37 words/sec, time elapsed 6005.78 sec
# epoch 7, iter 44450, avg. loss 30.89, avg. ppl 4.71 cum. examples 14400, speed 4665.28 words/sec, time elapsed 6007.15 sec
# epoch 7, iter 44460, avg. loss 29.21, avg. ppl 4.04 cum. examples 14720, speed 4710.45 words/sec, time elapsed 6008.57 sec
# epoch 7, iter 44470, avg. loss 32.78, avg. ppl 4.59 cum. examples 15040, speed 5041.15 words/sec, time elapsed 6009.93 sec
# epoch 7, iter 44480, avg. loss 32.90, avg. ppl 4.67 cum. examples 15360, speed 4901.50 words/sec, time elapsed 6011.33 sec
# epoch 7, iter 44490, avg. loss 28.61, avg. ppl 4.19 cum. examples 15680, speed 5058.08 words/sec, time elapsed 6012.59 sec
# epoch 7, iter 44500, avg. loss 29.41, avg. ppl 4.33 cum. examples 16000, speed 4701.52 words/sec, time elapsed 6013.96 sec
# epoch 7, iter 44510, avg. loss 33.08, avg. ppl 4.63 cum. examples 16320, speed 5166.00 words/sec, time elapsed 6015.29 sec
# epoch 7, iter 44520, avg. loss 30.44, avg. ppl 4.29 cum. examples 16640, speed 4848.13 words/sec, time elapsed 6016.67 sec
# epoch 7, iter 44530, avg. loss 30.45, avg. ppl 4.40 cum. examples 16960, speed 4527.69 words/sec, time elapsed 6018.13 sec
# epoch 7, iter 44540, avg. loss 30.90, avg. ppl 4.23 cum. examples 17280, speed 5066.48 words/sec, time elapsed 6019.48 sec
# epoch 7, iter 44550, avg. loss 30.89, avg. ppl 4.34 cum. examples 17600, speed 4774.95 words/sec, time elapsed 6020.89 sec
# epoch 7, iter 44560, avg. loss 31.77, avg. ppl 4.43 cum. examples 17920, speed 5335.69 words/sec, time elapsed 6022.17 sec
# epoch 7, iter 44570, avg. loss 29.41, avg. ppl 4.67 cum. examples 18240, speed 4496.01 words/sec, time elapsed 6023.53 sec
# epoch 7, iter 44580, avg. loss 30.48, avg. ppl 4.28 cum. examples 18560, speed 4610.84 words/sec, time elapsed 6024.98 sec
# epoch 7, iter 44590, avg. loss 30.49, avg. ppl 4.44 cum. examples 18880, speed 4904.68 words/sec, time elapsed 6026.32 sec
# epoch 7, iter 44600, avg. loss 32.78, avg. ppl 4.75 cum. examples 19200, speed 4845.74 words/sec, time elapsed 6027.71 sec
# epoch 7, iter 44610, avg. loss 29.14, avg. ppl 4.26 cum. examples 19520, speed 5125.16 words/sec, time elapsed 6028.96 sec
# epoch 7, iter 44620, avg. loss 30.77, avg. ppl 4.38 cum. examples 19840, speed 5018.66 words/sec, time elapsed 6030.29 sec
# epoch 7, iter 44630, avg. loss 27.68, avg. ppl 4.13 cum. examples 20160, speed 4795.59 words/sec, time elapsed 6031.59 sec
# epoch 7, iter 44640, avg. loss 30.82, avg. ppl 4.27 cum. examples 20480, speed 5022.87 words/sec, time elapsed 6032.95 sec
# epoch 7, iter 44650, avg. loss 32.57, avg. ppl 4.66 cum. examples 20800, speed 4794.28 words/sec, time elapsed 6034.36 sec
# epoch 7, iter 44660, avg. loss 31.23, avg. ppl 4.56 cum. examples 21120, speed 5004.78 words/sec, time elapsed 6035.68 sec
# epoch 7, iter 44670, avg. loss 30.30, avg. ppl 4.31 cum. examples 21440, speed 5052.99 words/sec, time elapsed 6036.99 sec
# epoch 7, iter 44680, avg. loss 33.86, avg. ppl 4.77 cum. examples 21760, speed 5057.30 words/sec, time elapsed 6038.36 sec
# epoch 7, iter 44690, avg. loss 27.90, avg. ppl 4.31 cum. examples 22080, speed 4613.12 words/sec, time elapsed 6039.69 sec
# epoch 7, iter 44700, avg. loss 29.82, avg. ppl 4.67 cum. examples 22400, speed 4894.53 words/sec, time elapsed 6040.95 sec
# epoch 7, iter 44710, avg. loss 32.60, avg. ppl 4.54 cum. examples 22720, speed 4885.66 words/sec, time elapsed 6042.36 sec
# epoch 7, iter 44720, avg. loss 30.62, avg. ppl 4.29 cum. examples 23040, speed 4859.31 words/sec, time elapsed 6043.75 sec
# epoch 7, iter 44730, avg. loss 29.69, avg. ppl 4.22 cum. examples 23360, speed 5000.23 words/sec, time elapsed 6045.07 sec
# epoch 7, iter 44740, avg. loss 29.63, avg. ppl 4.55 cum. examples 23680, speed 5041.75 words/sec, time elapsed 6046.31 sec
# epoch 7, iter 44750, avg. loss 30.48, avg. ppl 4.56 cum. examples 24000, speed 5392.06 words/sec, time elapsed 6047.50 sec
# epoch 7, iter 44760, avg. loss 31.14, avg. ppl 4.43 cum. examples 24320, speed 4876.26 words/sec, time elapsed 6048.87 sec
# epoch 7, iter 44770, avg. loss 29.71, avg. ppl 4.35 cum. examples 24640, speed 5181.08 words/sec, time elapsed 6050.12 sec
# epoch 7, iter 44780, avg. loss 31.27, avg. ppl 4.43 cum. examples 24960, speed 4877.27 words/sec, time elapsed 6051.50 sec
# epoch 7, iter 44790, avg. loss 32.84, avg. ppl 4.68 cum. examples 25280, speed 4762.24 words/sec, time elapsed 6052.93 sec
# epoch 7, iter 44800, avg. loss 31.13, avg. ppl 4.56 cum. examples 25600, speed 4868.25 words/sec, time elapsed 6054.28 sec
# epoch 7, iter 44810, avg. loss 30.38, avg. ppl 4.35 cum. examples 25920, speed 4712.15 words/sec, time elapsed 6055.68 sec
# epoch 7, iter 44820, avg. loss 28.12, avg. ppl 4.24 cum. examples 26240, speed 4881.74 words/sec, time elapsed 6056.96 sec
# epoch 7, iter 44830, avg. loss 30.89, avg. ppl 4.49 cum. examples 26560, speed 5075.45 words/sec, time elapsed 6058.25 sec
# epoch 7, iter 44840, avg. loss 31.77, avg. ppl 4.32 cum. examples 26880, speed 4874.04 words/sec, time elapsed 6059.68 sec
# epoch 7, iter 44850, avg. loss 33.15, avg. ppl 4.61 cum. examples 27200, speed 5075.48 words/sec, time elapsed 6061.05 sec
# epoch 7, iter 44860, avg. loss 34.76, avg. ppl 4.94 cum. examples 27520, speed 5189.36 words/sec, time elapsed 6062.39 sec
# epoch 7, iter 44870, avg. loss 32.02, avg. ppl 4.53 cum. examples 27840, speed 4989.18 words/sec, time elapsed 6063.75 sec
# epoch 7, iter 44880, avg. loss 28.65, avg. ppl 4.10 cum. examples 28160, speed 4666.39 words/sec, time elapsed 6065.14 sec
# epoch 7, iter 44890, avg. loss 31.66, avg. ppl 4.60 cum. examples 28480, speed 4667.15 words/sec, time elapsed 6066.56 sec
# epoch 7, iter 44900, avg. loss 31.25, avg. ppl 4.49 cum. examples 28800, speed 4784.70 words/sec, time elapsed 6067.96 sec
# epoch 7, iter 44910, avg. loss 32.90, avg. ppl 4.75 cum. examples 29120, speed 5128.84 words/sec, time elapsed 6069.28 sec
# epoch 7, iter 44920, avg. loss 30.34, avg. ppl 4.44 cum. examples 29440, speed 4774.72 words/sec, time elapsed 6070.64 sec
# epoch 7, iter 44930, avg. loss 31.08, avg. ppl 4.40 cum. examples 29760, speed 4755.45 words/sec, time elapsed 6072.05 sec
# epoch 7, iter 44940, avg. loss 34.49, avg. ppl 4.65 cum. examples 30080, speed 5159.75 words/sec, time elapsed 6073.44 sec
# epoch 7, iter 44950, avg. loss 32.14, avg. ppl 4.37 cum. examples 30400, speed 4700.20 words/sec, time elapsed 6074.93 sec
# epoch 7, iter 44960, avg. loss 28.85, avg. ppl 4.12 cum. examples 30720, speed 4733.24 words/sec, time elapsed 6076.30 sec
# epoch 7, iter 44970, avg. loss 31.97, avg. ppl 4.86 cum. examples 31040, speed 4624.71 words/sec, time elapsed 6077.70 sec
# epoch 7, iter 44980, avg. loss 29.69, avg. ppl 4.46 cum. examples 31360, speed 5116.02 words/sec, time elapsed 6078.94 sec
# epoch 7, iter 44990, avg. loss 30.99, avg. ppl 4.69 cum. examples 31680, speed 4908.81 words/sec, time elapsed 6080.25 sec
# epoch 7, iter 45000, avg. loss 31.54, avg. ppl 4.50 cum. examples 32000, speed 4600.27 words/sec, time elapsed 6081.71 sec
# epoch 7, iter 45010, avg. loss 30.88, avg. ppl 4.34 cum. examples 32320, speed 4918.05 words/sec, time elapsed 6083.08 sec
# epoch 7, iter 45020, avg. loss 29.52, avg. ppl 4.12 cum. examples 32640, speed 4660.47 words/sec, time elapsed 6084.51 sec
# ...
# epoch 14, iter 88750, avg. loss 26.76, avg. ppl 3.79 cum. examples 23977, speed 4627.95 words/sec, time elapsed 11946.30 sec
# epoch 14, iter 88760, avg. loss 27.48, avg. ppl 3.61 cum. examples 24297, speed 5018.69 words/sec, time elapsed 11947.66 sec
# epoch 14, iter 88770, avg. loss 27.81, avg. ppl 3.70 cum. examples 24617, speed 5073.61 words/sec, time elapsed 11949.01 sec
# epoch 14, iter 88780, avg. loss 28.72, avg. ppl 3.70 cum. examples 24937, speed 5356.46 words/sec, time elapsed 11950.32 sec
# epoch 14, iter 88790, avg. loss 25.60, avg. ppl 3.50 cum. examples 25257, speed 5206.04 words/sec, time elapsed 11951.57 sec
# epoch 14, iter 88800, avg. loss 25.79, avg. ppl 3.56 cum. examples 25577, speed 5057.68 words/sec, time elapsed 11952.86 sec
# epoch 14, iter 88810, avg. loss 27.06, avg. ppl 3.63 cum. examples 25897, speed 5106.54 words/sec, time elapsed 11954.18 sec
# epoch 14, iter 88820, avg. loss 24.71, avg. ppl 3.52 cum. examples 26217, speed 4791.46 words/sec, time elapsed 11955.49 sec
# epoch 14, iter 88830, avg. loss 25.54, avg. ppl 3.41 cum. examples 26537, speed 5126.80 words/sec, time elapsed 11956.79 sec
# epoch 14, iter 88840, avg. loss 26.44, avg. ppl 3.67 cum. examples 26857, speed 4840.83 words/sec, time elapsed 11958.13 sec
# epoch 14, iter 88850, avg. loss 25.28, avg. ppl 3.47 cum. examples 27177, speed 4920.76 words/sec, time elapsed 11959.45 sec
# epoch 14, iter 88860, avg. loss 25.27, avg. ppl 3.56 cum. examples 27497, speed 5408.98 words/sec, time elapsed 11960.63 sec
# epoch 14, iter 88870, avg. loss 26.05, avg. ppl 3.43 cum. examples 27817, speed 4904.28 words/sec, time elapsed 11962.01 sec
# epoch 14, iter 88880, avg. loss 25.40, avg. ppl 3.46 cum. examples 28137, speed 5365.64 words/sec, time elapsed 11963.23 sec
# epoch 14, iter 88890, avg. loss 28.32, avg. ppl 3.75 cum. examples 28457, speed 5036.03 words/sec, time elapsed 11964.59 sec
# epoch 14, iter 88900, avg. loss 26.07, avg. ppl 3.48 cum. examples 28777, speed 4730.06 words/sec, time elapsed 11966.01 sec
# epoch 14, iter 88910, avg. loss 28.32, avg. ppl 3.89 cum. examples 29097, speed 5052.48 words/sec, time elapsed 11967.33 sec
# epoch 14, iter 88920, avg. loss 27.76, avg. ppl 3.70 cum. examples 29417, speed 4808.15 words/sec, time elapsed 11968.74 sec
# epoch 14, iter 88930, avg. loss 26.37, avg. ppl 3.61 cum. examples 29737, speed 4971.93 words/sec, time elapsed 11970.06 sec
# epoch 14, iter 88940, avg. loss 24.26, avg. ppl 3.40 cum. examples 30057, speed 5080.48 words/sec, time elapsed 11971.31 sec
# epoch 14, iter 88950, avg. loss 26.80, avg. ppl 3.58 cum. examples 30377, speed 5167.59 words/sec, time elapsed 11972.61 sec
# epoch 14, iter 88960, avg. loss 26.75, avg. ppl 3.72 cum. examples 30697, speed 4929.93 words/sec, time elapsed 11973.93 sec
# epoch 14, iter 88970, avg. loss 26.97, avg. ppl 3.73 cum. examples 31017, speed 5063.82 words/sec, time elapsed 11975.23 sec
# epoch 14, iter 88980, avg. loss 24.77, avg. ppl 3.45 cum. examples 31337, speed 5020.95 words/sec, time elapsed 11976.51 sec
# epoch 14, iter 88990, avg. loss 26.25, avg. ppl 3.59 cum. examples 31657, speed 4944.64 words/sec, time elapsed 11977.84 sec
# epoch 14, iter 89000, avg. loss 29.88, avg. ppl 3.82 cum. examples 31977, speed 5051.20 words/sec, time elapsed 11979.25 sec
# epoch 14, iter 89010, avg. loss 27.02, avg. ppl 3.64 cum. examples 32297, speed 5202.70 words/sec, time elapsed 11980.54 sec
# epoch 14, iter 89020, avg. loss 25.92, avg. ppl 3.71 cum. examples 32617, speed 4972.32 words/sec, time elapsed 11981.81 sec
# epoch 14, iter 89030, avg. loss 26.06, avg. ppl 3.47 cum. examples 32937, speed 5093.07 words/sec, time elapsed 11983.12 sec
# epoch 14, iter 89040, avg. loss 26.14, avg. ppl 3.67 cum. examples 33257, speed 4975.03 words/sec, time elapsed 11984.42 sec
# epoch 14, iter 89050, avg. loss 26.89, avg. ppl 3.62 cum. examples 33577, speed 5129.10 words/sec, time elapsed 11985.72 sec
# epoch 14, iter 89060, avg. loss 25.37, avg. ppl 3.56 cum. examples 33897, speed 4953.89 words/sec, time elapsed 11987.01 sec
# epoch 14, iter 89070, avg. loss 25.25, avg. ppl 3.57 cum. examples 34217, speed 5066.73 words/sec, time elapsed 11988.27 sec
# epoch 14, iter 89080, avg. loss 26.04, avg. ppl 3.65 cum. examples 34537, speed 5014.85 words/sec, time elapsed 11989.55 sec
# epoch 14, iter 89090, avg. loss 25.57, avg. ppl 3.61 cum. examples 34857, speed 4664.68 words/sec, time elapsed 11990.91 sec
# epoch 14, iter 89100, avg. loss 25.33, avg. ppl 3.49 cum. examples 35177, speed 4622.31 words/sec, time elapsed 11992.32 sec
# epoch 14, iter 89110, avg. loss 25.42, avg. ppl 3.42 cum. examples 35497, speed 5041.67 words/sec, time elapsed 11993.63 sec
# epoch 14, iter 89120, avg. loss 25.13, avg. ppl 3.56 cum. examples 35817, speed 4978.50 words/sec, time elapsed 11994.90 sec
# epoch 14, iter 89130, avg. loss 27.93, avg. ppl 3.68 cum. examples 36137, speed 5056.87 words/sec, time elapsed 11996.26 sec
# epoch 14, iter 89140, avg. loss 26.53, avg. ppl 3.66 cum. examples 36457, speed 4805.07 words/sec, time elapsed 11997.62 sec
# epoch 14, iter 89150, avg. loss 28.74, avg. ppl 3.81 cum. examples 36777, speed 5033.16 words/sec, time elapsed 11998.99 sec
# epoch 14, iter 89160, avg. loss 27.94, avg. ppl 3.66 cum. examples 37097, speed 4707.20 words/sec, time elapsed 12000.45 sec
# epoch 14, iter 89170, avg. loss 23.99, avg. ppl 3.30 cum. examples 37417, speed 4914.16 words/sec, time elapsed 12001.76 sec
# epoch 14, iter 89180, avg. loss 26.78, avg. ppl 3.54 cum. examples 37737, speed 4735.49 words/sec, time elapsed 12003.19 sec
# epoch 14, iter 89190, avg. loss 26.52, avg. ppl 3.74 cum. examples 38057, speed 5020.12 words/sec, time elapsed 12004.47 sec
# epoch 14, iter 89200, avg. loss 25.90, avg. ppl 3.85 cum. examples 38377, speed 5076.90 words/sec, time elapsed 12005.68 sec
# epoch 14, iter 89210, avg. loss 27.10, avg. ppl 3.83 cum. examples 38697, speed 5026.90 words/sec, time elapsed 12006.97 sec
# epoch 14, iter 89220, avg. loss 29.75, avg. ppl 3.80 cum. examples 39017, speed 5299.52 words/sec, time elapsed 12008.31 sec
# epoch 14, iter 89230, avg. loss 25.97, avg. ppl 3.58 cum. examples 39337, speed 4762.60 words/sec, time elapsed 12009.68 sec
# epoch 14, iter 89240, avg. loss 24.16, avg. ppl 3.60 cum. examples 39657, speed 4909.23 words/sec, time elapsed 12010.91 sec
# epoch 14, iter 89250, avg. loss 25.26, avg. ppl 3.47 cum. examples 39977, speed 5168.33 words/sec, time elapsed 12012.17 sec
# epoch 14, iter 89260, avg. loss 29.72, avg. ppl 3.98 cum. examples 40297, speed 5052.85 words/sec, time elapsed 12013.53 sec
# epoch 14, iter 89270, avg. loss 29.06, avg. ppl 3.71 cum. examples 40617, speed 5305.29 words/sec, time elapsed 12014.87 sec
# epoch 14, iter 89280, avg. loss 25.73, avg. ppl 3.49 cum. examples 40937, speed 5281.74 words/sec, time elapsed 12016.11 sec
# epoch 14, iter 89290, avg. loss 24.16, avg. ppl 3.32 cum. examples 41257, speed 5048.82 words/sec, time elapsed 12017.39 sec
# epoch 14, iter 89300, avg. loss 24.09, avg. ppl 3.41 cum. examples 41577, speed 4754.47 words/sec, time elapsed 12018.71 sec
# epoch 14, iter 89310, avg. loss 27.69, avg. ppl 3.78 cum. examples 41897, speed 4836.87 words/sec, time elapsed 12020.09 sec
# epoch 14, iter 89320, avg. loss 27.53, avg. ppl 3.65 cum. examples 42217, speed 5135.23 words/sec, time elapsed 12021.41 sec
# epoch 14, iter 89330, avg. loss 28.26, avg. ppl 3.67 cum. examples 42537, speed 5219.29 words/sec, time elapsed 12022.74 sec
# epoch 14, iter 89340, avg. loss 27.41, avg. ppl 3.62 cum. examples 42857, speed 4894.85 words/sec, time elapsed 12024.14 sec
# epoch 14, iter 89350, avg. loss 25.34, avg. ppl 3.39 cum. examples 43177, speed 5114.72 words/sec, time elapsed 12025.44 sec
# epoch 14, iter 89360, avg. loss 25.41, avg. ppl 3.63 cum. examples 43497, speed 5124.84 words/sec, time elapsed 12026.67 sec
# epoch 14, iter 89370, avg. loss 24.87, avg. ppl 3.48 cum. examples 43817, speed 4671.41 words/sec, time elapsed 12028.03 sec
# epoch 14, iter 89380, avg. loss 24.19, avg. ppl 3.46 cum. examples 44137, speed 4598.88 words/sec, time elapsed 12029.39 sec
# epoch 14, iter 89390, avg. loss 27.57, avg. ppl 3.51 cum. examples 44457, speed 4880.55 words/sec, time elapsed 12030.83 sec
# epoch 14, iter 89400, avg. loss 28.55, avg. ppl 3.66 cum. examples 44777, speed 5096.68 words/sec, time elapsed 12032.21 sec
# epoch 14, iter 89410, avg. loss 26.05, avg. ppl 3.64 cum. examples 45097, speed 4918.91 words/sec, time elapsed 12033.52 sec
# epoch 14, iter 89420, avg. loss 26.38, avg. ppl 3.53 cum. examples 45417, speed 4949.84 words/sec, time elapsed 12034.88 sec
# epoch 14, iter 89430, avg. loss 26.37, avg. ppl 3.69 cum. examples 45737, speed 5026.06 words/sec, time elapsed 12036.16 sec
# epoch 14, iter 89440, avg. loss 28.40, avg. ppl 3.61 cum. examples 46057, speed 4856.79 words/sec, time elapsed 12037.62 sec
# epoch 14, iter 89450, avg. loss 27.20, avg. ppl 3.49 cum. examples 46377, speed 5054.87 words/sec, time elapsed 12039.00 sec
# epoch 14, iter 89460, avg. loss 24.44, avg. ppl 3.62 cum. examples 46697, speed 4526.02 words/sec, time elapsed 12040.34 sec
# epoch 14, iter 89470, avg. loss 26.96, avg. ppl 3.66 cum. examples 47017, speed 4774.59 words/sec, time elapsed 12041.73 sec
# epoch 14, iter 89480, avg. loss 24.22, avg. ppl 3.20 cum. examples 47337, speed 4753.46 words/sec, time elapsed 12043.13 sec
# epoch 14, iter 89490, avg. loss 27.47, avg. ppl 3.73 cum. examples 47657, speed 4762.53 words/sec, time elapsed 12044.54 sec
# epoch 14, iter 89500, avg. loss 26.18, avg. ppl 3.76 cum. examples 47977, speed 4882.12 words/sec, time elapsed 12045.83 sec
# epoch 14, iter 89510, avg. loss 26.52, avg. ppl 3.50 cum. examples 48297, speed 5148.51 words/sec, time elapsed 12047.15 sec
# epoch 14, iter 89520, avg. loss 26.13, avg. ppl 3.57 cum. examples 48617, speed 4962.85 words/sec, time elapsed 12048.47 sec
# epoch 14, iter 89530, avg. loss 26.14, avg. ppl 3.60 cum. examples 48937, speed 4791.13 words/sec, time elapsed 12049.83 sec
# epoch 14, iter 89540, avg. loss 26.15, avg. ppl 3.62 cum. examples 49257, speed 4938.09 words/sec, time elapsed 12051.15 sec
# epoch 14, iter 89550, avg. loss 24.46, avg. ppl 3.46 cum. examples 49577, speed 4859.50 words/sec, time elapsed 12052.45 sec
# epoch 14, iter 89560, avg. loss 27.03, avg. ppl 3.62 cum. examples 49897, speed 4757.59 words/sec, time elapsed 12053.86 sec
# epoch 14, iter 89570, avg. loss 26.72, avg. ppl 3.74 cum. examples 50217, speed 4613.82 words/sec, time elapsed 12055.27 sec
# epoch 14, iter 89580, avg. loss 29.12, avg. ppl 3.99 cum. examples 50537, speed 4555.23 words/sec, time elapsed 12056.75 sec
# epoch 14, iter 89590, avg. loss 25.29, avg. ppl 3.46 cum. examples 50857, speed 4991.89 words/sec, time elapsed 12058.05 sec
# epoch 14, iter 89600, avg. loss 26.87, avg. ppl 3.69 cum. examples 51177, speed 4864.74 words/sec, time elapsed 12059.41 sec
# epoch 14, iter 89610, avg. loss 28.92, avg. ppl 3.77 cum. examples 51497, speed 5695.24 words/sec, time elapsed 12060.63 sec
# epoch 14, iter 89620, avg. loss 25.90, avg. ppl 3.53 cum. examples 51817, speed 4843.90 words/sec, time elapsed 12061.99 sec
# epoch 14, iter 89630, avg. loss 26.10, avg. ppl 3.64 cum. examples 52137, speed 4564.34 words/sec, time elapsed 12063.40 sec
# epoch 14, iter 89640, avg. loss 24.68, avg. ppl 3.39 cum. examples 52457, speed 5023.89 words/sec, time elapsed 12064.69 sec
# epoch 14, iter 89650, avg. loss 27.43, avg. ppl 3.59 cum. examples 52777, speed 5220.10 words/sec, time elapsed 12066.01 sec
# epoch 14, iter 89660, avg. loss 28.88, avg. ppl 3.88 cum. examples 53097, speed 4793.60 words/sec, time elapsed 12067.43 sec
# epoch 14, iter 89670, avg. loss 27.37, avg. ppl 3.77 cum. examples 53417, speed 5450.50 words/sec, time elapsed 12068.64 sec
# epoch 14, iter 89680, avg. loss 25.95, avg. ppl 3.70 cum. examples 53737, speed 4951.28 words/sec, time elapsed 12069.92 sec
# epoch 14, iter 89690, avg. loss 24.31, avg. ppl 3.42 cum. examples 54057, speed 4942.82 words/sec, time elapsed 12071.20 sec
# epoch 14, iter 89700, avg. loss 25.07, avg. ppl 3.38 cum. examples 54377, speed 5199.69 words/sec, time elapsed 12072.47 sec
# epoch 14, iter 89710, avg. loss 24.07, avg. ppl 3.29 cum. examples 54697, speed 5011.37 words/sec, time elapsed 12073.76 sec
# epoch 14, iter 89720, avg. loss 26.72, avg. ppl 3.75 cum. examples 55017, speed 5281.63 words/sec, time elapsed 12074.99 sec
# epoch 14, iter 89730, avg. loss 26.89, avg. ppl 3.85 cum. examples 55337, speed 4651.17 words/sec, time elapsed 12076.36 sec
# epoch 14, iter 89740, avg. loss 25.18, avg. ppl 3.57 cum. examples 55657, speed 4538.81 words/sec, time elapsed 12077.75 sec
# epoch 14, iter 89750, avg. loss 29.35, avg. ppl 3.91 cum. examples 55977, speed 4873.39 words/sec, time elapsed 12079.17 sec
# epoch 14, iter 89760, avg. loss 24.98, avg. ppl 3.42 cum. examples 56297, speed 4666.26 words/sec, time elapsed 12080.56 sec
# epoch 14, iter 89770, avg. loss 28.16, avg. ppl 3.80 cum. examples 56617, speed 5081.29 words/sec, time elapsed 12081.89 sec
# epoch 14, iter 89780, avg. loss 24.75, avg. ppl 3.57 cum. examples 56937, speed 4637.57 words/sec, time elapsed 12083.23 sec
# epoch 14, iter 89790, avg. loss 22.71, avg. ppl 3.18 cum. examples 57257, speed 4823.64 words/sec, time elapsed 12084.53 sec
# epoch 14, iter 89800, avg. loss 25.42, avg. ppl 3.41 cum. examples 57577, speed 4970.80 words/sec, time elapsed 12085.86 sec
# epoch 14, iter 89810, avg. loss 25.60, avg. ppl 3.56 cum. examples 57897, speed 4907.47 words/sec, time elapsed 12087.18 sec
# epoch 14, iter 89820, avg. loss 26.34, avg. ppl 3.51 cum. examples 58217, speed 4998.27 words/sec, time elapsed 12088.52 sec
# epoch 14, iter 89830, avg. loss 27.49, avg. ppl 3.77 cum. examples 58537, speed 5253.06 words/sec, time elapsed 12089.78 sec
# epoch 14, iter 89840, avg. loss 25.17, avg. ppl 3.40 cum. examples 58857, speed 4884.48 words/sec, time elapsed 12091.13 sec
# epoch 14, iter 89850, avg. loss 25.83, avg. ppl 3.44 cum. examples 59177, speed 5004.50 words/sec, time elapsed 12092.47 sec
# epoch 14, iter 89860, avg. loss 25.81, avg. ppl 3.39 cum. examples 59497, speed 5037.46 words/sec, time elapsed 12093.81 sec
# epoch 14, iter 89870, avg. loss 25.82, avg. ppl 3.52 cum. examples 59817, speed 4908.19 words/sec, time elapsed 12095.15 sec
# epoch 14, iter 89880, avg. loss 23.17, avg. ppl 3.41 cum. examples 60137, speed 4828.65 words/sec, time elapsed 12096.40 sec
# epoch 14, iter 89890, avg. loss 27.46, avg. ppl 3.63 cum. examples 60457, speed 4982.24 words/sec, time elapsed 12097.77 sec
# epoch 14, iter 89900, avg. loss 24.93, avg. ppl 3.54 cum. examples 60777, speed 5238.38 words/sec, time elapsed 12098.97 sec
# epoch 14, iter 89910, avg. loss 27.17, avg. ppl 3.75 cum. examples 61097, speed 4703.66 words/sec, time elapsed 12100.37 sec
# epoch 14, iter 89920, avg. loss 28.18, avg. ppl 3.68 cum. examples 61417, speed 4987.82 words/sec, time elapsed 12101.76 sec
# epoch 14, iter 89930, avg. loss 26.82, avg. ppl 3.61 cum. examples 61737, speed 4695.83 words/sec, time elapsed 12103.18 sec
# epoch 14, iter 89940, avg. loss 27.45, avg. ppl 3.66 cum. examples 62057, speed 4927.97 words/sec, time elapsed 12104.55 sec
# epoch 14, iter 89950, avg. loss 26.18, avg. ppl 3.57 cum. examples 62377, speed 5176.54 words/sec, time elapsed 12105.83 sec
# epoch 14, iter 89960, avg. loss 25.40, avg. ppl 3.34 cum. examples 62697, speed 5106.55 words/sec, time elapsed 12107.15 sec
# epoch 14, iter 89970, avg. loss 26.69, avg. ppl 3.49 cum. examples 63017, speed 5067.55 words/sec, time elapsed 12108.50 sec
# epoch 14, iter 89980, avg. loss 25.99, avg. ppl 3.59 cum. examples 63337, speed 4779.80 words/sec, time elapsed 12109.86 sec
# epoch 14, iter 89990, avg. loss 27.87, avg. ppl 3.93 cum. examples 63657, speed 4860.24 words/sec, time elapsed 12111.20 sec
# epoch 14, iter 90000, avg. loss 26.28, avg. ppl 3.55 cum. examples 63977, speed 4783.92 words/sec, time elapsed 12112.59 sec
# epoch 14, iter 90000, cum. loss 26.32, cum. ppl 3.59 cum. examples 63977
# begin validation ...
# validation: iter 90000, dev. ppl 7.196822
# hit patience 5
# hit #5 trial
# early stop!

# %%
# !sh run.sh test
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding:   0% 0/8064 [00:00<?, ?it/s]/pytorch/aten/src/ATen/native/BinaryOps.cpp:81: UserWarning: Integer division of tensors using div or / is deprecated, and in a future release div will perform true division as in Python 3. Use true_divide or floor_divide (// in Python) instead.
# Decoding: 100% 8064/8064 [12:11<00:00, 11.02it/s]
# Corpus BLEU: 35.68593352628277

# %% [markdown]
# #details of the edited code

# %% [markdown]
# ##utils

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
CS224N 2019-20: Homework 4
nmt.py: NMT Model
Pencheng Yin <pcyin@cs.cmu.edu>
Sahil Chopra <schopra8@stanford.edu>
Vera Lin <veralin@stanford.edu>
"""

import math
from typing import List

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import nltk
nltk.download('punkt')


def pad_sents(sents, pad_token):
    """ Pad list of sentences according to the longest sentence in the batch.
        The paddings should be at the end of each sentence.
    @param sents (list[list[str]]): list of sentences, where each sentence
                                    is represented as a list of words
    @param pad_token (str): padding token
    @returns sents_padded (list[list[str]]): list of sentences where sentences shorter
        than the max length sentence are padded out with the pad_token, such that
        each sentences in the batch now has equal length.
    """
    sents_padded = []
    max_length=0
    ### YOUR CODE HERE (~6 Lines)
    for sent in sents:
      if len(sent)>max_lenght:
        max_length=len(sent)


    for sent in sents:
      new_sent=[]
      new_sent.extend(sent)
      for i in range(max_length-len(sent)):
        new_sent.append(pad_token)
      sents_padded.append(new_sent)
      # if len(sent)<max_length:
      #   padding=max_length-len(sent)
      #   start_pad=padding//2
      #   if padding%2==0:
      #     end_pad=padding//2
      #   else:
      #     end_pad=(padding//2)+1
        # for i in range(start_pad):
        #   new_sent.append(pad_token)
        # new_sent.extend(sent)
        # for i in range(end_padding):
        #   sent.append(pad_token)


      # sents_padded.append(new_sent)
        







    ### END YOUR CODE

    return sents_padded


def read_corpus(file_path, source):
    """ Read file, where each sentence is dilineated by a `\n`.
    @param file_path (str): path to file containing corpus
    @param source (str): "tgt" or "src" indicating whether text
        is of the source language or target language
    """
    data = []
    for line in open(file_path):
        sent = nltk.word_tokenize(line)
        # only append <s> and </s> to the target sentence
        if source == 'tgt':
            sent = ['<s>'] + sent + ['</s>']
        data.append(sent)

    return data


def batch_iter(data, batch_size, shuffle=False):
    """ Yield batches of source and target sentences reverse sorted by length (largest to smallest).
    @param data (list of (src_sent, tgt_sent)): list of tuples containing source and target sentence
    @param batch_size (int): batch size
    @param shuffle (boolean): whether to randomly shuffle the dataset
    """
    batch_num = math.ceil(len(data) / batch_size)
    index_array = list(range(len(data)))

    if shuffle:
        np.random.shuffle(index_array)

    for i in range(batch_num):
        indices = index_array[i * batch_size: (i + 1) * batch_size]
        examples = [data[idx] for idx in indices]

        examples = sorted(examples, key=lambda e: len(e[0]), reverse=True)
        src_sents = [e[0] for e in examples]
        tgt_sents = [e[1] for e in examples]

        yield src_sents, tgt_sents
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ##Model Embeddings

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
CS224N 2019-20: Homework 4
model_embeddings.py: Embeddings for the NMT model
Pencheng Yin <pcyin@cs.cmu.edu>
Sahil Chopra <schopra8@stanford.edu>
Anand Dhoot <anandd@stanford.edu>
Vera Lin <veralin@stanford.edu>
"""

import torch.nn as nn

class ModelEmbeddings(nn.Module): 
    """
    Class that converts input words to their embeddings.
    """
    def __init__(self, embed_size, vocab):
        """
        Init the Embedding layers.

        @param embed_size (int): Embedding size (dimensionality)
        @param vocab (Vocab): Vocabulary object containing src and tgt languages
                              See vocab.py for documentation.
        """
        super(ModelEmbeddings, self).__init__()
        self.embed_size = embed_size

        # default values
        self.source = None
        self.target = None

        src_pad_token_idx = vocab.src['<pad>']
        tgt_pad_token_idx = vocab.tgt['<pad>']

        ### YOUR CODE HERE (~2 Lines)
        ### TODO - Initialize the following variables:
        ###     self.source (Embedding Layer for source language)
        ###     self.target (Embedding Layer for target langauge)
        ###
        ### Note:
        ###     1. `vocab` object contains two vocabularies:
        ###            `vocab.src` for source
        ###            `vocab.tgt` for target
        ###     2. You can get the length of a specific vocabulary by running:
        ###             `len(vocab.<specific_vocabulary>)`
        ###     3. Remember to include the padding token for the specific vocabulary
        ###        when creating your Embedding.
        ###
        ### Use the following docs to properly initialize these variables:
        ###     Embedding Layer:
        ###         https://pytorch.org/docs/stable/nn.html#torch.nn.Embedding
        
        self.source = torch.nn.Embedding(len(vocab.src), embed_size, padding_idx=src_pad_token_idx,)
        self.target = torch.nn.Embedding(len(vocab.tgt), embed_size, padding_idx=src_pad_token_idx)
        ### END YOUR CODE

# %% [markdown]
# ##NMT model

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
CS224N 2019-20: Homework 4
nmt_model.py: NMT Model
Pencheng Yin <pcyin@cs.cmu.edu>
Sahil Chopra <schopra8@stanford.edu>
Vera Lin <veralin@stanford.edu>
"""
from collections import namedtuple
import sys
from typing import List, Tuple, Dict, Set, Union
import torch
import torch.nn as nn
import torch.nn.utils
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_packed_sequence, pack_padded_sequence

# from model_embeddings import ModelEmbeddings
Hypothesis = namedtuple('Hypothesis', ['value', 'score'])


class NMT(nn.Module):
    """ Simple Neural Machine Translation Model:
        - Bidrectional LSTM Encoder
        - Unidirection LSTM Decoder
        - Global Attention Model (Luong, et al. 2015)
    """
    def __init__(self, embed_size, hidden_size, vocab, dropout_rate=0.2):
        """ Init NMT Model.

        @param embed_size (int): Embedding size (dimensionality)
        @param hidden_size (int): Hidden Size, the size of hidden states (dimensionality)
        @param vocab (Vocab): Vocabulary object containing src and tgt languages
                              See vocab.py for documentation.
        @param dropout_rate (float): Dropout probability, for attention
        """
        super(NMT, self).__init__()
        self.model_embeddings = ModelEmbeddings(embed_size, vocab)
        self.hidden_size = hidden_size
        self.dropout_rate = dropout_rate
        self.vocab = vocab

        # default values
        self.encoder = None 
        self.decoder = None
        self.h_projection = None
        self.c_projection = None
        self.att_projection = None
        self.combined_output_projection = None
        self.target_vocab_projection = None
        self.dropout = None
        # For sanity check only, not relevant to implementation
        self.gen_sanity_check = False
        self.counter = 0


        ### YOUR CODE HERE (~8 Lines)
        ### TODO - Initialize the following variables:
        ###     self.encoder (Bidirectional LSTM with bias)
        ###     self.decoder (LSTM Cell with bias)
        ###     self.h_projection (Linear Layer with no bias), called W_{h} in the PDF.
        ###     self.c_projection (Linear Layer with no bias), called W_{c} in the PDF.
        ###     self.att_projection (Linear Layer with no bias), called W_{attProj} in the PDF.
        ###     self.combined_output_projection (Linear Layer with no bias), called W_{u} in the PDF.
        ###     self.target_vocab_projection (Linear Layer with no bias), called W_{vocab} in the PDF.
        ###     self.dropout (Dropout Layer)
        ###
        ### Use the following docs to properly initialize these variables:
        ###     LSTM:
        ###         https://pytorch.org/docs/stable/nn.html#torch.nn.LSTM
        ###     LSTM Cell:
        ###         https://pytorch.org/docs/stable/nn.html#torch.nn.LSTMCell
        ###     Linear Layer:
        ###         https://pytorch.org/docs/stable/nn.html#torch.nn.Linear
        ###     Dropout Layer:
        ###         https://pytorch.org/docs/stable/nn.html#torch.nn.Dropout
        self.encoder=torch.nn.LSTM(embed_size, hidden_size, bias=True, bidirectional=True)
        self.decoder=torch.nn.LSTMCell(embed_size + hidden_size, hidden_size, bias=True)
        self.h_projection = torch.nn.Linear(hidden_size * 2, hidden_size, bias=False)
        self.c_projection = torch.nn.Linear(hidden_size * 2, hidden_size, bias=False)
        self.att_projection = torch.nn.Linear(hidden_size * 2, hidden_size, bias=False)
        self.combined_output_projection = torch.nn.Linear(hidden_size * 3, hidden_size, bias=False)
        self.target_vocab_projection = torch.nn.Linear(hidden_size, len(vocab.tgt), bias=False)
        self.dropout=torch.nn.Dropout(p=dropout_rate, inplace=False)

        ### END YOUR CODE


    def forward(self, source: List[List[str]], target: List[List[str]]) -> torch.Tensor:
        """ Take a mini-batch of source and target sentences, compute the log-likelihood of
        target sentences under the language models learned by the NMT system.

        @param source (List[List[str]]): list of source sentence tokens
        @param target (List[List[str]]): list of target sentence tokens, wrapped by `<s>` and `</s>`

        @returns scores (Tensor): a variable/tensor of shape (b, ) representing the
                                    log-likelihood of generating the gold-standard target sentence for
                                    each example in the input batch. Here b = batch size.
        """
        # Compute sentence lengths
        source_lengths = [len(s) for s in source]

        # Convert list of lists into tensors
        source_padded = self.vocab.src.to_input_tensor(source, device=self.device)   # Tensor: (src_len, b)
        target_padded = self.vocab.tgt.to_input_tensor(target, device=self.device)   # Tensor: (tgt_len, b)

        ###     Run the network forward:
        ###     1. Apply the encoder to `source_padded` by calling `self.encode()`
        ###     2. Generate sentence masks for `source_padded` by calling `self.generate_sent_masks()`
        ###     3. Apply the decoder to compute combined-output by calling `self.decode()`
        ###     4. Compute log probability distribution over the target vocabulary using the
        ###        combined_outputs returned by the `self.decode()` function.

        enc_hiddens, dec_init_state = self.encode(source_padded, source_lengths)
        enc_masks = self.generate_sent_masks(enc_hiddens, source_lengths)
        combined_outputs = self.decode(enc_hiddens, enc_masks, dec_init_state, target_padded)
        P = F.log_softmax(self.target_vocab_projection(combined_outputs), dim=-1)

        # Zero out, probabilities for which we have nothing in the target text
        target_masks = (target_padded != self.vocab.tgt['<pad>']).float()
        
        # Compute log probability of generating true target words
        target_gold_words_log_prob = torch.gather(P, index=target_padded[1:].unsqueeze(-1), dim=-1).squeeze(-1) * target_masks[1:]
        scores = target_gold_words_log_prob.sum(dim=0)
        return scores


    def encode(self, source_padded: torch.Tensor, source_lengths: List[int]) -> Tuple[torch.Tensor, Tuple[torch.Tensor, torch.Tensor]]:
        """ Apply the encoder to source sentences to obtain encoder hidden states.
            Additionally, take the final states of the encoder and project them to obtain initial states for decoder.

        @param source_padded (Tensor): Tensor of padded source sentences with shape (src_len, b), where
                                        b = batch_size, src_len = maximum source sentence length. Note that 
                                       these have already been sorted in order of longest to shortest sentence.
        @param source_lengths (List[int]): List of actual lengths for each of the source sentences in the batch
        @returns enc_hiddens (Tensor): Tensor of hidden units with shape (b, src_len, h*2), where
                                        b = batch size, src_len = maximum source sentence length, h = hidden size.
        @returns dec_init_state (tuple(Tensor, Tensor)): Tuple of tensors representing the decoder's initial
                                                hidden state and cell.
        """
        enc_hiddens, dec_init_state = None, None

        ### YOUR CODE HERE (~ 8 Lines)
        ### TODO:
        ###     1. Construct Tensor `X` of source sentences with shape (src_len, b, e) using the source model embeddings.
        ###         src_len = maximum source sentence length, b = batch size, e = embedding size. Note
        ###         that there is no initial hidden state or cell for the decoder.
        ###     2. Compute `enc_hiddens`, `last_hidden`, `last_cell` by applying the encoder to `X`.
        ###         - Before you can apply the encoder, you need to apply the `pack_padded_sequence` function to X.
        ###         - After you apply the encoder, you need to apply the `pad_packed_sequence` function to enc_hiddens.
        ###         - Note that the shape of the tensor returned by the encoder is (src_len, b, h*2) and we want to
        ###           return a tensor of shape (b, src_len, h*2) as `enc_hiddens`.
        ###     3. Compute `dec_init_state` = (init_decoder_hidden, init_decoder_cell):
        ###         - `init_decoder_hidden`:
        ###             `last_hidden` is a tensor shape (2, b, h). The first dimension corresponds to forwards and backwards.
        ###             Concatenate the forwards and backwards tensors to obtain a tensor shape (b, 2*h).
        ###             Apply the h_projection layer to this in order to compute init_decoder_hidden.
        ###             This is h_0^{dec} in the PDF. Here b = batch size, h = hidden size
        ###         - `init_decoder_cell`:
        ###             `last_cell` is a tensor shape (2, b, h). The first dimension corresponds to forwards and backwards.
        ###             Concatenate the forwards and backwards tensors to obtain a tensor shape (b, 2*h).
        ###             Apply the c_projection layer to this in order to compute init_decoder_cell.
        ###             This is c_0^{dec} in the PDF. Here b = batch size, h = hidden size
        ###
        ### See the following docs, as you may need to use some of the following functions in your implementation:
        ###     Pack the padded sequence X before passing to the encoder:
        ###         https://pytorch.org/docs/stable/nn.html#torch.nn.utils.rnn.pack_padded_sequence
        ###     Pad the packed sequence, enc_hiddens, returned by the encoder:
        ###         https://pytorch.org/docs/stable/nn.html#torch.nn.utils.rnn.pad_packed_sequence
        ###     Tensor Concatenation:
        ###         https://pytorch.org/docs/stable/torch.html#torch.cat
        ###     Tensor Permute:
        ###         https://pytorch.org/docs/stable/tensors.html#torch.Tensor.permute
        X = self.model_embeddings.source(source_padded) # (src_len, b, e)
        X = pack_padded_sequence(X, lengths=source_lengths) #packing is used to prepare the input to LSTM
        enc_hiddens, (last_hidden, last_cell) = self.encoder(X)
        
        enc_hiddens, _ = pad_packed_sequence(enc_hiddens)   
        enc_hiddens = enc_hiddens.transpose(0, 1) 

        last_hidden = torch.cat((last_hidden[0], last_hidden[1]), 1)
        init_decoder_hidden = self.h_projection(last_hidden)

        last_cell   = torch.cat((last_cell[0], last_cell[1]), 1)
        init_decoder_cell   = self.c_projection(last_cell)

        dec_init_state = (init_decoder_hidden, init_decoder_cell)



        ### END YOUR CODE

        return enc_hiddens, dec_init_state


    def decode(self, enc_hiddens: torch.Tensor, enc_masks: torch.Tensor,
                dec_init_state: Tuple[torch.Tensor, torch.Tensor], target_padded: torch.Tensor) -> torch.Tensor:
        """Compute combined output vectors for a batch.

        @param enc_hiddens (Tensor): Hidden states (b, src_len, h*2), where
                                     b = batch size, src_len = maximum source sentence length, h = hidden size.
        @param enc_masks (Tensor): Tensor of sentence masks (b, src_len), where
                                     b = batch size, src_len = maximum source sentence length.
        @param dec_init_state (tuple(Tensor, Tensor)): Initial state and cell for decoder
        @param target_padded (Tensor): Gold-standard padded target sentences (tgt_len, b), where
                                       tgt_len = maximum target sentence length, b = batch size. 

        @returns combined_outputs (Tensor): combined output tensor  (tgt_len, b,  h), where
                                        tgt_len = maximum target sentence length, b = batch_size,  h = hidden size
        """
        # Chop of the <END> token for max length sentences.
        target_padded = target_padded[:-1]

        # Initialize the decoder state (hidden and cell)
        dec_state = dec_init_state

        # Initialize previous combined output vector o_{t-1} as zero
        batch_size = enc_hiddens.size(0)
        o_prev = torch.zeros(batch_size, self.hidden_size, device=self.device)

        # Initialize a list we will use to collect the combined output o_t on each step
        combined_outputs = []

        ### YOUR CODE HERE (~9 Lines)
        ### TODO:
        ###     1. Apply the attention projection layer to `enc_hiddens` to obtain `enc_hiddens_proj`,
        ###         which should be shape (b, src_len, h),
        ###         where b = batch size, src_len = maximum source length, h = hidden size.
        ###         This is applying W_{attProj} to h^enc, as described in the PDF.
        ###     2. Construct tensor `Y` of target sentences with shape (tgt_len, b, e) using the target model embeddings.
        ###         where tgt_len = maximum target sentence length, b = batch size, e = embedding size.
        ###     3. Use the torch.split function to iterate over the time dimension of Y.
        ###         Within the loop, this will give you Y_t of shape (1, b, e) where b = batch size, e = embedding size.
        ###             - Squeeze Y_t into a tensor of dimension (b, e). 
        ###             - Construct Ybar_t by concatenating Y_t with o_prev on their last dimension
        ###             - Use the step function to compute the the Decoder's next (cell, state) values
        ###               as well as the new combined output o_t.
        ###             - Append o_t to combined_outputs
        ###             - Update o_prev to the new o_t.
        ###     4. Use torch.stack to convert combined_outputs from a list length tgt_len of
        ###         tensors shape (b, h), to a single tensor shape (tgt_len, b, h)
        ###         where tgt_len = maximum target sentence length, b = batch size, h = hidden size.
        ###
        ### Note:
        ###    - When using the squeeze() function make sure to specify the dimension you want to squeeze
        ###      over. Otherwise, you will remove the batch dimension accidentally, if batch_size = 1.
        ###   
        ### You may find some of these functions useful:
        ###     Zeros Tensor:
        ###         https://pytorch.org/docs/stable/torch.html#torch.zeros
        ###     Tensor Splitting (iteration):
        ###         https://pytorch.org/docs/stable/torch.html#torch.split
        ###     Tensor Dimension Squeezing:
        ###         https://pytorch.org/docs/stable/torch.html#torch.squeeze
        ###     Tensor Concatenation:
        ###         https://pytorch.org/docs/stable/torch.html#torch.cat
        ###     Tensor Stacking:
        ###         https://pytorch.org/docs/stable/torch.html#torch.stack

        enc_hiddens_proj=self.att_projection(enc_hiddens)
        Y=self.model_embeddings.target(target_padded)
        for y_t in torch.split(Y,1):
          y_t=torch.squeeze(y_t)
          ybar_t=torch.cat((y_t,o_prev),dim=1)
          dec_state, new_o_t, _ = self.step(ybar_t, dec_state, enc_hiddens, enc_hiddens_proj, enc_masks)

          combined_outputs.append(new_o_t)
          o_prev=new_o_t


        combined_outputs = torch.stack(combined_outputs, dim=0)





        ### END YOUR CODE

        return combined_outputs


    def step(self, Ybar_t: torch.Tensor,
            dec_state: Tuple[torch.Tensor, torch.Tensor],
            enc_hiddens: torch.Tensor,
            enc_hiddens_proj: torch.Tensor,
            enc_masks: torch.Tensor) -> Tuple[Tuple, torch.Tensor, torch.Tensor]:
        """ Compute one forward step of the LSTM decoder, including the attention computation.

        @param Ybar_t (Tensor): Concatenated Tensor of [Y_t o_prev], with shape (b, e + h). The input for the decoder,
                                where b = batch size, e = embedding size, h = hidden size.
        @param dec_state (tuple(Tensor, Tensor)): Tuple of tensors both with shape (b, h), where b = batch size, h = hidden size.
                First tensor is decoder's prev hidden state, second tensor is decoder's prev cell.
        @param enc_hiddens (Tensor): Encoder hidden states Tensor, with shape (b, src_len, h * 2), where b = batch size,
                                    src_len = maximum source length, h = hidden size.
        @param enc_hiddens_proj (Tensor): Encoder hidden states Tensor, projected from (h * 2) to h. Tensor is with shape (b, src_len, h),
                                    where b = batch size, src_len = maximum source length, h = hidden size.
        @param enc_masks (Tensor): Tensor of sentence masks shape (b, src_len),
                                    where b = batch size, src_len is maximum source length. 

        @returns dec_state (tuple (Tensor, Tensor)): Tuple of tensors both shape (b, h), where b = batch size, h = hidden size.
                First tensor is decoder's new hidden state, second tensor is decoder's new cell.
        @returns combined_output (Tensor): Combined output Tensor at timestep t, shape (b, h), where b = batch size, h = hidden size.
        @returns e_t (Tensor): Tensor of shape (b, src_len). It is attention scores distribution.
                                Note: You will not use this outside of this function.
                                      We are simply returning this value so that we can sanity check
                                      your implementation.
        """

        combined_output = None

        ### YOUR CODE HERE (~3 Lines)
        ### TODO:
        ###     1. Apply the decoder to `Ybar_t` and `dec_state`to obtain the new dec_state.
        ###     2. Split dec_state into its two parts (dec_hidden, dec_cell)
        ###     3. Compute the attention scores e_t, a Tensor shape (b, src_len). 
        ###        Note: b = batch_size, src_len = maximum source length, h = hidden size.
        ###
        ###       Hints:
        ###         - dec_hidden is shape (b, h) and corresponds to h^dec_t in the PDF (batched)
        ###         - enc_hiddens_proj is shape (b, src_len, h) and corresponds to W_{attProj} h^enc (batched).
        ###         - Use batched matrix multiplication (torch.bmm) to compute e_t (be careful about the input/ output shapes!)
        ###         - To get the tensors into the right shapes for bmm, you will need to do some squeezing and unsqueezing.
        ###         - When using the squeeze() function make sure to specify the dimension you want to squeeze
        ###             over. Otherwise, you will remove the batch dimension accidentally, if batch_size = 1.
        ###
        ### Use the following docs to implement this functionality:
        ###     Batch Multiplication:
        ###        https://pytorch.org/docs/stable/torch.html#torch.bmm
        ###     Tensor Unsqueeze:
        ###         https://pytorch.org/docs/stable/torch.html#torch.unsqueeze
        ###     Tensor Squeeze:
        ###         https://pytorch.org/docs/stable/torch.html#torch.squeeze
        dec_state=self.decoder(Ybar_t,dec_state)
        (dec_hidden,dec_cell)=dec_state
        e_t=enc_hiddens_proj.bmm(dec_hidden.unsqueeze(2)).squeeze(2)


        ### END YOUR CODE

        # Set e_t to -inf where enc_masks has 1
        if enc_masks is not None:
            e_t.data.masked_fill_(enc_masks.bool(), -float('inf'))

        ### YOUR CODE HERE (~6 Lines)
        ### TODO:
        ###     1. Apply softmax to e_t to yield alpha_t
        ###     2. Use batched matrix multiplication between alpha_t and enc_hiddens to obtain the
        ###         attention output vector, a_t.
        ###           - alpha_t is shape (b, src_len)
        ###           - enc_hiddens is shape (b, src_len, 2h)
        ###           - a_t should be shape (b, 2h)
        ###           - You will need to do some squeezing and unsqueezing.
        ###     Note: b = batch size, src_len = maximum source length, h = hidden size.
        ###
        ###     3. Concatenate dec_hidden with a_t to compute tensor U_t
        ###     4. Apply the combined output projection layer to U_t to compute tensor V_t
        ###     5. Compute tensor O_t by first applying the Tanh function and then the dropout layer.
        ###
        ### Use the following docs to implement this functionality:
        ###     Softmax:
        ###         https://pytorch.org/docs/stable/nn.html#torch.nn.functional.softmax
        ###     Batch Multiplication:
        ###        https://pytorch.org/docs/stable/torch.html#torch.bmm
        ###     Tensor View:
        ###         https://pytorch.org/docs/stable/tensors.html#torch.Tensor.view
        ###     Tensor Concatenation:
        ###         https://pytorch.org/docs/stable/torch.html#torch.cat
        ###     Tanh:
        ###         https://pytorch.org/docs/stable/torch.html#torch.tanh
        # 1, apply softmax to e_t
        alpha_t = F.softmax(e_t, dim=1) # (b, src_len)
        att_view = (alpha_t.size(0), 1, alpha_t.size(1))
        a_t = torch.bmm(alpha_t.view(*att_view), enc_hiddens).squeeze(1)

        U_t = torch.cat((a_t, dec_hidden), dim=1)
        V_t = self.combined_output_projection(U_t)
        O_t = self.dropout(torch.tanh(V_t))


        ### END YOUR CODE

        combined_output = O_t
        return dec_state, combined_output, e_t

    def generate_sent_masks(self, enc_hiddens: torch.Tensor, source_lengths: List[int]) -> torch.Tensor:
        """ Generate sentence masks for encoder hidden states.

        @param enc_hiddens (Tensor): encodings of shape (b, src_len, 2*h), where b = batch size,
                                     src_len = max source length, h = hidden size. 
        @param source_lengths (List[int]): List of actual lengths for each of the sentences in the batch.
        
        @returns enc_masks (Tensor): Tensor of sentence masks of shape (b, src_len),
                                    where src_len = max source length, h = hidden size.
        """
        enc_masks = torch.zeros(enc_hiddens.size(0), enc_hiddens.size(1), dtype=torch.float)
        for e_id, src_len in enumerate(source_lengths):
            enc_masks[e_id, src_len:] = 1
        return enc_masks.to(self.device)


    def beam_search(self, src_sent: List[str], beam_size: int=5, max_decoding_time_step: int=70) -> List[Hypothesis]:
        """ Given a single source sentence, perform beam search, yielding translations in the target language.
        @param src_sent (List[str]): a single source sentence (words)
        @param beam_size (int): beam size
        @param max_decoding_time_step (int): maximum number of time steps to unroll the decoding RNN
        @returns hypotheses (List[Hypothesis]): a list of hypothesis, each hypothesis has two fields:
                value: List[str]: the decoded target sentence, represented as a list of words
                score: float: the log-likelihood of the target sentence
        """
        src_sents_var = self.vocab.src.to_input_tensor([src_sent], self.device)

        src_encodings, dec_init_vec = self.encode(src_sents_var, [len(src_sent)])
        src_encodings_att_linear = self.att_projection(src_encodings)

        h_tm1 = dec_init_vec
        att_tm1 = torch.zeros(1, self.hidden_size, device=self.device)

        eos_id = self.vocab.tgt['</s>']

        hypotheses = [['<s>']]
        hyp_scores = torch.zeros(len(hypotheses), dtype=torch.float, device=self.device)
        completed_hypotheses = []

        t = 0
        while len(completed_hypotheses) < beam_size and t < max_decoding_time_step:
            t += 1
            hyp_num = len(hypotheses)

            exp_src_encodings = src_encodings.expand(hyp_num,
                                                     src_encodings.size(1),
                                                     src_encodings.size(2))

            exp_src_encodings_att_linear = src_encodings_att_linear.expand(hyp_num,
                                                                           src_encodings_att_linear.size(1),
                                                                           src_encodings_att_linear.size(2))

            y_tm1 = torch.tensor([self.vocab.tgt[hyp[-1]] for hyp in hypotheses], dtype=torch.long, device=self.device)
            y_t_embed = self.model_embeddings.target(y_tm1)

            x = torch.cat([y_t_embed, att_tm1], dim=-1)

            (h_t, cell_t), att_t, _  = self.step(x, h_tm1,
                                                      exp_src_encodings, exp_src_encodings_att_linear, enc_masks=None)

            # log probabilities over target words
            log_p_t = F.log_softmax(self.target_vocab_projection(att_t), dim=-1)

            live_hyp_num = beam_size - len(completed_hypotheses)
            contiuating_hyp_scores = (hyp_scores.unsqueeze(1).expand_as(log_p_t) + log_p_t).view(-1)
            top_cand_hyp_scores, top_cand_hyp_pos = torch.topk(contiuating_hyp_scores, k=live_hyp_num)

            prev_hyp_ids = top_cand_hyp_pos / len(self.vocab.tgt)
            hyp_word_ids = top_cand_hyp_pos % len(self.vocab.tgt)

            new_hypotheses = []
            live_hyp_ids = []
            new_hyp_scores = []

            for prev_hyp_id, hyp_word_id, cand_new_hyp_score in zip(prev_hyp_ids, hyp_word_ids, top_cand_hyp_scores):
                prev_hyp_id = prev_hyp_id.item()
                hyp_word_id = hyp_word_id.item()
                cand_new_hyp_score = cand_new_hyp_score.item()

                hyp_word = self.vocab.tgt.id2word[hyp_word_id]
                new_hyp_sent = hypotheses[prev_hyp_id] + [hyp_word]
                if hyp_word == '</s>':
                    completed_hypotheses.append(Hypothesis(value=new_hyp_sent[1:-1],
                                                           score=cand_new_hyp_score))
                else:
                    new_hypotheses.append(new_hyp_sent)
                    live_hyp_ids.append(prev_hyp_id)
                    new_hyp_scores.append(cand_new_hyp_score)

            if len(completed_hypotheses) == beam_size:
                break

            live_hyp_ids = torch.tensor(live_hyp_ids, dtype=torch.long, device=self.device)
            h_tm1 = (h_t[live_hyp_ids], cell_t[live_hyp_ids])
            att_tm1 = att_t[live_hyp_ids]

            hypotheses = new_hypotheses
            hyp_scores = torch.tensor(new_hyp_scores, dtype=torch.float, device=self.device)

        if len(completed_hypotheses) == 0:
            completed_hypotheses.append(Hypothesis(value=hypotheses[0][1:],
                                                   score=hyp_scores[0].item()))

        completed_hypotheses.sort(key=lambda hyp: hyp.score, reverse=True)

        return completed_hypotheses

    @property
    def device(self) -> torch.device:
        """ Determine which device to place the Tensors upon, CPU or GPU.
        """
        return self.model_embeddings.source.weight.device

    @staticmethod
    def load(model_path: str):
        """ Load the model from a file.
        @param model_path (str): path to model
        """
        params = torch.load(model_path, map_location=lambda storage, loc: storage)
        args = params['args']
        model = NMT(vocab=params['vocab'], **args)
        model.load_state_dict(params['state_dict'])

        return model

    def save(self, path: str):
        """ Save the odel to a file.
        @param path (str): path to the model
        """
        print('save model parameters to [%s]' % path, file=sys.stderr)

        params = {
            'args': dict(embed_size=self.model_embeddings.embed_size, hidden_size=self.hidden_size, dropout_rate=self.dropout_rate),
            'vocab': self.vocab,
            'state_dict': self.state_dict()
        }

        torch.save(params, path)

# %%
# !python sanity_check.py 1f
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 1f: Step
# --------------------------------------------------------------------------------
# dec_state[0] Sanity Checks Passed!
# dec_state[1] Sanity Checks Passed!
# combined_output  Sanity Checks Passed!
# e_t Sanity Checks Passed!
# --------------------------------------------------------------------------------
# All Sanity Checks Passed for Question 1f: Step!
# --------------------------------------------------------------------------------

# %%
# !sh run.sh vocab
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# read in source sentences: ./en_es_data/train.es
# read in target sentences: ./en_es_data/train.en
